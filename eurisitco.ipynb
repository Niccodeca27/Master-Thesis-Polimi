# %% [markdown]
# # Modello euristico

# %% [markdown]
# ## Import pacchetti

# %%
# ------------------------------------------------------------
# 0) IMPORT
# ------------------------------------------------------------
from tabnanny import verbose
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor, as_completed
import pickle


# Notebook esterno con tutte le funzioni di routing
import import_ipynb
import performance_calc as pc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650547 entries, 0 to 650546
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   location_id     650547 non-null  int64
#  1   lat             650547 non-null  float64
#  2   lon             650547 non-null  float64
#  3   quantity        650547 non-null  int64
#  4   delivery_date   650547 non-null  object
#  5   window_start_0  639992 non-null  object
#  6   window_end_0    639992 non-null  object
#  7   is_event        650547 non-null  int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 39.7+ MB
# ❌ Valori non convertiti in 'delivery_date':
# []
#
# ❌ Valori non convertibili in booleani in 'is_event':
# []
# <string>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True False False ...  True  True  True]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ❌ Valori non convertiti in window_start_0:
# [None]
#
# ❌ Valori non convertiti in window_end_0:
# [None]
# <class 'pandas.core.frame.DataFrame'>
# Index: 63733 entries, 0 to 650546
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location_id     63733 non-null  int64
#  1   lat             63733 non-null  float64
#  2   lon             63733 non-null  float64
#  3   quantity        63733 non-null  int64
#  4   delivery_date   63733 non-null  datetime64[ns]
#  5   window_start_0  63590 non-null  object
#  6   window_end_0    63590 non-null  object
#  7   is_event        63733 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 4.4+ MB
# Punti di consegna unici trovati: 3766
# Dopo l'eliminazione di punti troppo distanti, sono rimasti 3764 punti di consegna
# delivery points esempio:
#    location_id        lat        lon
# 0         2884  45.710720  10.047550
# 1         2885  45.670435   9.935415
# 2         2886  45.671596   9.931096
# 3         2888  45.683688  10.020058
# 4         2889  45.666919   9.660539

# %% [markdown]
# ## Implementazione modello euristico

# %% [markdown]
# ## Last try - Problemi memoria

# %%
def clustering_euristico_multicluster(full_time_mat_min: np.ndarray,
                                      index_to_location_id: list[int],
                                      delivery_points: pd.DataFrame,
                                      max_time: int = 500,
                                      unloading_time: int = 10):
    """
    Algoritmo Cluster‐First, Route‐Second:
    • seed = punto più distante dal deposito
    • greedy: aggiunge il punto che allunga meno il tour
    • stop quando supererebbe max_time
    """
    n_points = full_time_mat_min.shape[0]
    unassigned = set(range(1, n_points))          # deposito è indice 0
    clusters = []


    while unassigned:
        # --- nuovo cluster
        first_idx = max(unassigned, key=lambda i: full_time_mat_min[0, i])
        cluster = [first_idx]
        unassigned.remove(first_idx)
        cluster_time = full_time_mat_min[0, first_idx] * 2 + unloading_time


        # --- inserimento greedy
        while unassigned:
            # tempo minimo dal cluster al candidato
            cand, min_cost = min(
                ((c, min(full_time_mat_min[p, c] for p in cluster)) for c in unassigned),
                key=lambda x: x[1]
            )
            if cluster_time + min_cost + unloading_time > max_time:
                break
            cluster.append(cand)
            unassigned.remove(cand)
            cluster_time += min_cost + unloading_time


        clusters.append([index_to_location_id[i] for i in cluster])


    return clusters



def plot_clusters(clusters, delivery_points, title):
    """Visual plot rapido"""
    cmap = plt.cm.get_cmap("tab20", len(clusters))
    plt.figure(figsize=(10, 7))
    for i, cl in enumerate(clusters):
        sub = delivery_points[delivery_points["location_id"].isin(cl)]
        plt.scatter(sub["lon"], sub["lat"], c=[cmap(i)],
                    label=f"C{i+1}", alpha=.7, s=20, edgecolors="k")
    plt.title(title)
    plt.xlabel("lon"); plt.ylabel("lat")
    plt.legend(ncol=2, fontsize="small")
    plt.show()


def deduplicate_clusters(clusters, already_assigned_points):
    """
    Rimuove punti già assegnati dai cluster e restituisce solo cluster validi
    
    Args:
        clusters: lista di cluster (liste di location_id)
        already_assigned_points: set di location_id già assegnati
        
    Returns:
        result: lista di cluster puliti
        assigned: set aggiornato di punti assegnati
    """
    assigned = set(already_assigned_points)
    result = []
    
    for cluster in clusters:
        clean_cluster = [loc_id for loc_id in cluster if loc_id not in assigned]
        if clean_cluster:  # Solo se il cluster ha almeno un punto
            result.append(clean_cluster)
            assigned.update(clean_cluster)
    
    return result, assigned


def get_last_iteration_rejected_clusters(all_results, already_assigned_points, verbose=True):
    """
    Recupera i cluster RIFIUTATI dell'ULTIMA iterazione, filtrando i punti già assegnati
    
    Args:
        all_results: dizionario con i risultati di tutte le iterazioni
        already_assigned_points: set di location_id già assegnati
        verbose: stampa messaggi di debug
        
    Returns:
        lista di cluster filtrati
    """
    if not all_results:
        return []
    
    # Prendi l'ultima iterazione
    last_iteration = max(all_results.keys())
    last_results = all_results[last_iteration]
    
    # Recupera i cluster rifiutati
    rejected_cluster_indices = last_results['rejected_indices']
    all_clusters = last_results['clusters']
    rejected_clusters = [all_clusters[i] for i in rejected_cluster_indices]
    
    if verbose:
        print(f"   🔍 Recuperando cluster rifiutati dall'ultima iterazione ({last_iteration})")
        print(f"   📋 Cluster rifiutati disponibili: {len(rejected_clusters)}")
    
    # Filtra punti già assegnati
    filtered_clusters, _ = deduplicate_clusters(rejected_clusters, already_assigned_points)
    
    if verbose:
        total_points = sum(len(cl) for cl in filtered_clusters)
        print(f"   ✅ Cluster recuperati dopo filtro: {len(filtered_clusters)} ({total_points} punti)")
    
    return filtered_clusters


def count_clusters_with_excessive_overtime(performance_df, threshold=1):
    """
    Conta quanti cluster hanno più di 'threshold' giorni di overtime
    
    Args:
        performance_df: DataFrame con le performance dei cluster
        threshold: soglia di overtime (default 1)
        
    Returns:
        numero di cluster con overtime > threshold
    """
    count = 0
    for cluster_name, cluster_data in performance_df.groupby('cluster'):
        total_overtime = cluster_data['n_overtime_days'].sum()
        if total_overtime > threshold:
            count += 1
    return count



def evaluate_and_accept_clusters(clusters, performance_df, verbose=True):
    """
    Valuta i cluster e decide quali accettare basandosi sui criteri:
    1) Media giornaliera tra 390-480 minuti
    2) Overtime accettabile (massimo 1 giorno per tipo di giorno della settimana)
    
    Returns:
        accepted_clusters: list di cluster (liste di location_id) accettati
        rejected_indices: list di indici dei cluster rifiutati
    """
    accepted_clusters = []
    rejected_indices = []
    
    # Raggruppa performance per cluster
    for cluster_name, cluster_data in performance_df.groupby('cluster'):
        cluster_index = int(cluster_name.split()[-1]) - 1  # "Cluster 1" -> index 0
        cluster = clusters[cluster_index]
        
        # CRITERIO 1: Media giornaliera tra 390-480 minuti
        mean_minutes_range = cluster_data['mean_minutes'].between(390, 480).any()
        
        # CRITERIO 2: Overtime accettabile
        overtime_acceptable = check_overtime_acceptable(cluster_data)
        
        if mean_minutes_range or overtime_acceptable:
            accepted_clusters.append(cluster)
            if verbose:
                max_mean = cluster_data['mean_minutes'].max()
                total_overtime = cluster_data['n_overtime_days'].sum()
                reason = "mean_range" if mean_minutes_range else "overtime_ok"
                print(f"      ✅ {cluster_name}: {len(cluster)} punti, "
                      f"max_mean={max_mean:.1f}min, overtime={total_overtime}, "
                      f"motivo={reason}")
        else:
            rejected_indices.append(cluster_index)
            if verbose:
                max_mean = cluster_data['mean_minutes'].max()
                total_overtime = cluster_data['n_overtime_days'].sum()
                print(f"      ❌ {cluster_name}: {len(cluster)} punti, "
                      f"max_mean={max_mean:.1f}min, overtime={total_overtime}, "
                      f"RIFIUTATO")
    
    return accepted_clusters, rejected_indices



def check_overtime_acceptable(cluster_data):
    """
    Controlla se l'overtime è accettabile:
    massimo 1 giorno di overtime per ogni giorno della settimana
    
    Args:
        cluster_data: DataFrame con performance di un singolo cluster
    
    Returns:
        bool: True se overtime accettabile, False altrimenti
    """
    # Controlla per ogni giorno della settimana
    for _, row in cluster_data.iterrows():
        if row['n_overtime_days'] > 1:  # Più di 1 giorno di overtime per questo weekday -> non accettato
            return False
        elif row['n_overtime_days'] == 1:
            return True  # Ok, 1 giorno di overtime è accettabile
    
    return False






def assemble_final_performance_from_cache(all_results, final_complete_clusters, verbose=True):
    """
    Assembla un DataFrame finale dalle performance già calcolate nelle iterazioni.
    Molto più veloce del ricalcolo completo.
    """
    if verbose:
        print("📋 Assemblando performance finali da cache esistenti...")
    
    final_performance_pieces = []
    cluster_counter = 1
    
    for cluster in final_complete_clusters:
        cluster_found = False
        
        # Cerca questo cluster nelle iterazioni passate
        for iteration_num, results in all_results.items():
            for i, iter_cluster in enumerate(results['clusters']):
                if set(iter_cluster) == set(cluster):  # Stesso cluster
                    # Prendi le performance già calcolate
                    iter_perf_df = results['performance_df']
                    cluster_name_old = f"Cluster {i+1}"
                    cluster_data = iter_perf_df[iter_perf_df['cluster'] == cluster_name_old].copy()
                    
                    # Rinomina con il nuovo indice
                    cluster_data['cluster'] = f"Cluster {cluster_counter}"
                    final_performance_pieces.append(cluster_data)
                    cluster_counter += 1
                    cluster_found = True
                    break
            
            if cluster_found:
                break
        
        if not cluster_found and verbose:
            print(f"   ⚠️ Cluster non trovato in cache - dovrà essere ricalcolato")
    
    if final_performance_pieces:
        final_df = pd.concat(final_performance_pieces, ignore_index=True)
        if verbose:
            print(f"   ✅ Assemblate performance per {len(final_performance_pieces)} cluster da cache")
        return final_df
    else:
        if verbose:
            print("   ⚠️ Nessuna performance in cache - calcolo completo necessario")
        return None



def heuristic_iterative_clustering_complete(delivery_points: pd.DataFrame,
                                           depot_location: tuple[float, float],
                                           initial_threshold: int = 800,
                                           increment_threshold: int = 120,
                                           unload_min: int = 10,
                                           max_iterations: int = 10,
                                           verbose: bool = True,
                                           enable_diagnostics: bool = False):
    """
    Algoritmo iterativo che restituisce TUTTI i punti assegnati a cluster.
    MODIFICHE:
    - Ogni punto assegnato ad un solo cluster (no duplicati)
    - Fallback all'ultima iterazione per punti non assegnati
    - Refinement automatico se >5 cluster con overtime >1
    
    Returns:
        all_results: dict con tutti i risultati intermedi
        final_complete_clusters: list di TUTTI i cluster (accettati + migliori fallback)
        final_performance: DataFrame con performance di tutti i cluster finali
        refinement_applied: bool indicante se è stato applicato refinement
    """
    
    if verbose:
        print("🔄 INIZIO clustering iterativo COMPLETO con soglia crescente")
        print(f"   • Soglia iniziale: {initial_threshold} min")
        print(f"   • Incremento: +{increment_threshold} min per iterazione")
    
    all_results = {}
    remaining_points = delivery_points.copy()
    original_points = set(delivery_points['location_id'])
    already_assigned_points = set()  # NUOVO: Traccia globale dei punti già assegnati
    current_threshold = initial_threshold
    
    for iteration in range(max_iterations):
        if verbose:
            print(f"\n🔄 Iterazione {iteration + 1}: soglia = {current_threshold} min")
            print(f"   • Punti rimanenti: {len(remaining_points)}")
        
        if remaining_points.empty:
            if verbose:
                print("   ✅ Nessun punto rimanente - STOP")
            break
        
        # ================== CLUSTERING ==================
        dm, tm, idx2loc, _ = pc.distance_matrix_creation('', remaining_points)
        clusters = clustering_euristico_multicluster(
            tm, idx2loc, remaining_points,
            max_time=current_threshold,
            unloading_time=unload_min
        )
        
        if not clusters:
            if verbose:
                print("   ⚠️ Nessun cluster generato - STOP")
            break
        
        # ================== PERFORMANCE ==================
        performance_df = pc.calc_clusters_stats_AS(
            clusters, time_limit=3, parallel=True, max_workers=7, verbose=False
        )
        
        # ================== VALUTAZIONE E ACCETTAZIONE ==================
        accepted_clusters, rejected_cluster_indices = evaluate_and_accept_clusters(
            clusters, performance_df, verbose=verbose
        )
        
        # Salva risultati dell'iterazione (con rejected_indices invece di rejected_clusters)
        all_results[iteration + 1] = {
            'threshold': current_threshold,
            'clusters': clusters,
            'performance_df': performance_df,
            'accepted_clusters': accepted_clusters,
            'rejected_indices': rejected_cluster_indices
        }
        
        if verbose:
            print(f"   ✅ Cluster accettati: {len(accepted_clusters)}/{len(clusters)}")
        
        # ================== RIMOZIONE PUNTI ACCETTATI (NO DUPLICATI) ==================
        accepted_location_ids = set()
        for cluster in accepted_clusters:
            accepted_location_ids.update(cluster)
        
        # NUOVO: Filtra solo gli ID che esistono effettivamente nel DataFrame
        existing_ids = set(remaining_points['location_id'])
        valid_accepted_ids = accepted_location_ids.intersection(existing_ids)
        missing_ids = accepted_location_ids - existing_ids
        
        if verbose and missing_ids:
            print(f'   ⚠️ ID nei cluster ma non nel DataFrame: {len(missing_ids)} ID')
            print(f'   🔧 ID validi da rimuovere: {len(valid_accepted_ids)} ID')
        
        # NUOVO: Aggiorna il set globale dei punti assegnati
        already_assigned_points.update(valid_accepted_ids)

        # PER LA DIAGNOSTICA (opzionale):
        if enable_diagnostics and verbose:
            remaining_points_after_removal = remaining_points[
                ~remaining_points["location_id"].isin(valid_accepted_ids)
            ].copy()
            diagnose_point_removal(remaining_points, accepted_clusters, 
                remaining_points_after_removal, iteration + 1)
        
        # USA VALID_ACCEPTED_IDS invece di ACCEPTED_LOCATION_IDS
        remaining_points = remaining_points[
            ~remaining_points['location_id'].isin(valid_accepted_ids)
        ].copy()
        
        # Se tutti i cluster sono stati accettati, abbiamo finito
        if len(accepted_clusters) == len(clusters):
            if verbose:
                print("   🎯 Tutti i cluster sono stati accettati - STOP")
            break
        
        # Incrementa soglia per prossima iterazione
        current_threshold += increment_threshold
    
    # ================== ASSEMBLAGGIO FINALE ==================
    if verbose:
        print(f"\n🔧 Assemblaggio soluzione finale...")
    
    final_complete_clusters = []
    
    # 1. Aggiungi tutti i cluster accettati (già senza duplicati)
    for iteration_results in all_results.values():
        for cluster in iteration_results['accepted_clusters']:
            final_complete_clusters.append(cluster)
    
    # 2. NUOVO: Per i punti rimanenti, usa i cluster RIFIUTATI dell'ULTIMA ITERAZIONE
    unassigned_points = original_points - already_assigned_points
    
    if unassigned_points:
        if verbose:
            print(f"   📋 Punti non assegnati: {len(unassigned_points)}")
            print("   🔍 Recuperando cluster rifiutati dall'ultima iterazione...")
        
        last_iteration_clusters = get_last_iteration_rejected_clusters(
            all_results, already_assigned_points, verbose
        )
        
        final_complete_clusters.extend(last_iteration_clusters)
        for cluster in last_iteration_clusters:
            already_assigned_points.update(cluster)
    
    # ================== PERFORMANCE FINALI ==================
    if verbose:
        print(f"\n📊 Calcolando performance finali per {len(final_complete_clusters)} cluster...")
    
    # Calcola performance (senza cache per ora, per evitare problemi)
    final_performance = pc.calc_clusters_stats_AS(
        final_complete_clusters, time_limit=3, parallel=True, max_workers=7, verbose=False
    )
    
    if verbose:
        total_points = sum(len(cluster) for cluster in final_complete_clusters)
        print(f"\n🏁 COMPLETATO:")
        print(f"   • Iterazioni eseguite: {len(all_results)}")
        print(f"   • Cluster finali totali: {len(final_complete_clusters)}")
        print(f"   • Punti totali assegnati: {total_points}")
        print(f"   • Copertura: {total_points}/{len(original_points)} punti")
        
        missing = len(original_points) - total_points
        if missing > 0:
            print(f"   ⚠️ Punti mancanti: {missing}")
    
    # ================== CHECK OVERTIME ECCESSIVO E REFINEMENT ==================
    excessive_overtime_count = count_clusters_with_excessive_overtime(final_performance, threshold=1)
    
    if verbose:
        print(f"\n📊 Cluster con più di 1 giorno overtime: {excessive_overtime_count}")
    
    # NUOVO: Se ci sono più di 5 cluster con overtime eccessivo, applica refinement
    refinement_needed = excessive_overtime_count > 5
    
    if refinement_needed:
        if verbose:
            print(f"\n🔄 REFINEMENT NECESSARIO: {excessive_overtime_count} cluster con overtime > 1")
            print("   🚀 Avvio 5 cicli aggiuntivi con soglia 1550 min (+60/iterazione)...")
        
        # Identifica i punti nei cluster problematici
        problematic_points = set()
        problematic_cluster_names = []
        for cluster_name, cluster_data in final_performance.groupby('cluster'):
            total_overtime = cluster_data['n_overtime_days'].sum()
            if total_overtime > 1:
                problematic_cluster_names.append(cluster_name)
                cluster_index = int(cluster_name.split()[-1]) - 1
                problematic_cluster = final_complete_clusters[cluster_index]
                problematic_points.update(problematic_cluster)
        
        # Crea DataFrame con i punti problematici
        refinement_points = delivery_points[
            delivery_points['location_id'].isin(problematic_points)
        ].copy()
        
        if verbose:
            print(f"   📋 Cluster problematici: {len(problematic_cluster_names)}")
            print(f"   📋 Punti da riclusterare: {len(refinement_points)}")
        
        # Applica refinement (ricorsivo)
        refinement_results, refinement_clusters, refinement_performance, _ = heuristic_iterative_clustering_complete(
            delivery_points=refinement_points,
            depot_location=depot_location,
            initial_threshold=1550,  # NUOVO: soglia più alta
            increment_threshold=60,   # NUOVO: incremento più piccolo
            unload_min=unload_min,
            max_iterations=5,        # NUOVO: max 5 iterazioni
            verbose=verbose,
            enable_diagnostics=False  # Disabilita diagnostica nel refinement
        )
        
        # Sostituisci i cluster problematici con quelli raffinati
        final_complete_clusters = [
            cl for cl in final_complete_clusters 
            if not any(p in problematic_points for p in cl)
        ]
        final_complete_clusters.extend(refinement_clusters)
        
        # Ricalcola performance finali
        final_performance = pc.calc_clusters_stats_AS(
            final_complete_clusters, time_limit=3, parallel=True, max_workers=7, verbose=False
        )
        
        if verbose:
            print(f"\n✅ REFINEMENT COMPLETATO")
            print(f"   • Nuovi cluster totali: {len(final_complete_clusters)}")
            excessive_after = count_clusters_with_excessive_overtime(final_performance, threshold=1)
            print(f"   • Cluster con overtime > 1: {excessive_after} (prima: {excessive_overtime_count})")
        
        return all_results, final_complete_clusters, final_performance, True
    
    return all_results, final_complete_clusters, final_performance, False





def plot_iteration_results(all_results, delivery_points, iteration_to_plot=None):
    """
    Plotta i risultati di una specifica iterazione o dell'ultima
    """
    if iteration_to_plot is None:
        iteration_to_plot = max(all_results.keys())
    
    if iteration_to_plot not in all_results:
        print(f"Iterazione {iteration_to_plot} non trovata")
        return
    
    results = all_results[iteration_to_plot]
    clusters = results['clusters']
    threshold = results['threshold']
    accepted = results['accepted_clusters']
    
    plot_clusters(clusters, delivery_points, 
                  f"Iterazione {iteration_to_plot} - Soglia {threshold} min "
                  f"({len(accepted)} accettati/{len(clusters)} totali)")



# ------------------------------------------------
# ----------------------------------------------------------------------------------------
# SOLO PER DEBUG
# ----------------------------------------------------------------------------------------
# ------------------------------------------------


def diagnose_point_removal(remaining_points_before, accepted_clusters, remaining_points_after, iteration):
    """Diagnostica dettagliata per capire la discrepanza"""
    
    print(f"\n🔍 DIAGNOSTICA ITERAZIONE {iteration}:")
    
    # 1. Conta punti prima
    points_before = len(remaining_points_before)
    print(f"   📊 Punti prima: {points_before}")
    
    # 2. Conta punti negli cluster accettati
    accepted_location_ids = set()
    total_accepted_points = 0
    for i, cluster in enumerate(accepted_clusters):
        cluster_size = len(cluster)
        total_accepted_points += cluster_size
        accepted_location_ids.update(cluster)
        print(f"   ✅ Cluster {i+1}: {cluster_size} punti")
    
    print(f"   📊 Totale punti accettati: {total_accepted_points}")
    print(f"   📊 Location_ID unici accettati: {len(accepted_location_ids)}")
    
    # 3. Verifica che tutti i location_id accettati esistano in remaining_points_before
    existing_ids = set(remaining_points_before['location_id'])
    missing_ids = accepted_location_ids - existing_ids
    if missing_ids:
        print(f"   ⚠️ PROBLEMA: {len(missing_ids)} ID accettati non esistono in remaining_points!")
        print(f"      ID mancanti: {list(missing_ids)[:10]}...")
    
    # 4. Simula la rimozione manualmente
    should_remain = remaining_points_before[
        ~remaining_points_before['location_id'].isin(accepted_location_ids)
    ]
    expected_remaining = len(should_remain)
    
    # 5. Conta punti dopo
    points_after = len(remaining_points_after)
    print(f"   📊 Punti dopo rimozione: {points_after}")
    print(f"   📊 Punti attesi dopo rimozione: {expected_remaining}")
    
    # 6. Calcola discrepanze
    actual_removed = points_before - points_after
    expected_removed = len(accepted_location_ids)
    discrepancy = total_accepted_points - actual_removed
    
    print(f"   📊 Rimossi effettivamente: {actual_removed}")
    print(f"   📊 Dovevano essere rimossi: {expected_removed}")
    print(f"   📊 DISCREPANZA: {discrepancy}")
    
    if discrepancy != 0:
        print(f"   ❌ DISCREPANZA RILEVATA!")
        
        # Analisi più profonda
        if points_after != expected_remaining:
            print(f"   🔍 Il DataFrame finale non corrisponde alla simulazione")
            print(f"   🔍 Differenza: {points_after - expected_remaining}")
    
    print(f"   ✅ Diagnostica completata\n")
    
    return {
        'points_before': points_before,
        'total_accepted_points': total_accepted_points,
        'actual_removed': actual_removed,
        'discrepancy': discrepancy
    }

# ------------------------------------------------
# ----------------------------------------------------------------------------------------
# FINE DEBUG
# ----------------------------------------------------------------------------------------
# ------------------------------------------------

# %% [markdown]
# ### Run

# %%
import time
start = time.time()

all_results, final_clusters, final_performance, refinement_applied = heuristic_iterative_clustering_complete(
    delivery_points=pc.delivery_points_AS,
    depot_location=pc.depot_location,
    initial_threshold=800,
    increment_threshold=100,
    unload_min=10,
    max_iterations=15,
    verbose=True,
    enable_diagnostics=True  # Metti False per disabilitare la diagnostica
)


end = time.time()
print(f"Tempo di esecuzione algoritmo: {(end - start)/60:.2f} min")


# Stampa risultato refinement
if refinement_applied:
    print("\n🎯 REFINEMENT APPLICATO con successo!")
else:
    print("\n✅ NESSUN REFINEMENT necessario - soluzione ottimale trovata")
# Out:
# 🔄 INIZIO clustering iterativo COMPLETO con soglia crescente
#    • Soglia iniziale: 800 min
#    • Incremento: +100 min per iterazione
#
# 🔄 Iterazione 1: soglia = 800 min
#    • Punti rimanenti: 2972
#       ✅ Cluster 1: 41 punti, max_mean=461.4min, overtime=2, motivo=mean_range
#       ❌ Cluster 10: 52 punti, max_mean=268.9min, overtime=0, RIFIUTATO
#       ✅ Cluster 11: 50 punti, max_mean=313.1min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 12: 57 punti, max_mean=320.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 57 punti, max_mean=270.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 50 punti, max_mean=213.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 54 punti, max_mean=260.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 55 punti, max_mean=231.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 58 punti, max_mean=183.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 54 punti, max_mean=256.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 54 punti, max_mean=289.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 45 punti, max_mean=264.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 57 punti, max_mean=208.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 57 punti, max_mean=212.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 54 punti, max_mean=275.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 56 punti, max_mean=266.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 57 punti, max_mean=180.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 60 punti, max_mean=266.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 56 punti, max_mean=319.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 60 punti, max_mean=177.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 59 punti, max_mean=239.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 56 punti, max_mean=246.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 47 punti, max_mean=356.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 56 punti, max_mean=201.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 61 punti, max_mean=204.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 56 punti, max_mean=139.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 61 punti, max_mean=203.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 61 punti, max_mean=201.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 61 punti, max_mean=206.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 63 punti, max_mean=205.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 57 punti, max_mean=216.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 64 punti, max_mean=199.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 65 punti, max_mean=177.6min, overtime=0, RIFIUTATO
#       ✅ Cluster 4: 47 punti, max_mean=423.4min, overtime=0, motivo=mean_range
#       ❌ Cluster 40: 64 punti, max_mean=223.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 41: 64 punti, max_mean=180.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 42: 67 punti, max_mean=172.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 43: 63 punti, max_mean=153.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 44: 67 punti, max_mean=180.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 45: 68 punti, max_mean=193.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 46: 66 punti, max_mean=184.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 47: 68 punti, max_mean=139.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 48: 64 punti, max_mean=152.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 49: 67 punti, max_mean=157.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 50 punti, max_mean=350.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 50: 65 punti, max_mean=116.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 51: 66 punti, max_mean=126.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 52: 35 punti, max_mean=91.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 47 punti, max_mean=281.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 50 punti, max_mean=275.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 54 punti, max_mean=332.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 49 punti, max_mean=252.8min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 3/52
#
# 🔍 DIAGNOSTICA ITERAZIONE 1:
#    📊 Punti prima: 2972
#    ✅ Cluster 1: 41 punti
#    ✅ Cluster 2: 50 punti
#    ✅ Cluster 3: 47 punti
#    📊 Totale punti accettati: 138
#    📊 Location_ID unici accettati: 138
#    📊 Punti dopo rimozione: 2834
#    📊 Punti attesi dopo rimozione: 2834
#    📊 Rimossi effettivamente: 138
#    📊 Dovevano essere rimossi: 138
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 2: soglia = 900 min
#    • Punti rimanenti: 2834
#       ❌ Cluster 1: 53 punti, max_mean=273.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 65 punti, max_mean=321.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 58 punti, max_mean=234.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 65 punti, max_mean=271.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 66 punti, max_mean=240.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 62 punti, max_mean=235.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 63 punti, max_mean=256.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 63 punti, max_mean=299.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 64 punti, max_mean=227.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 62 punti, max_mean=278.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 66 punti, max_mean=178.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 55 punti, max_mean=378.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 64 punti, max_mean=201.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 65 punti, max_mean=343.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 66 punti, max_mean=255.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 67 punti, max_mean=217.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 67 punti, max_mean=229.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 68 punti, max_mean=258.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 68 punti, max_mean=203.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 65 punti, max_mean=235.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 68 punti, max_mean=242.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 65 punti, max_mean=192.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 58 punti, max_mean=360.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 70 punti, max_mean=246.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 64 punti, max_mean=226.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 71 punti, max_mean=211.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 73 punti, max_mean=197.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 74 punti, max_mean=263.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 77 punti, max_mean=197.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 76 punti, max_mean=171.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 74 punti, max_mean=236.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 76 punti, max_mean=185.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 76 punti, max_mean=148.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 55 punti, max_mean=280.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 40: 75 punti, max_mean=176.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 41: 75 punti, max_mean=175.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 42: 72 punti, max_mean=135.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 43: 62 punti, max_mean=155.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 59 punti, max_mean=279.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 63 punti, max_mean=332.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 56 punti, max_mean=254.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 62 punti, max_mean=307.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 61 punti, max_mean=299.9min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/43
#
# 🔍 DIAGNOSTICA ITERAZIONE 2:
#    📊 Punti prima: 2834
#    📊 Totale punti accettati: 0
#    📊 Location_ID unici accettati: 0
#    📊 Punti dopo rimozione: 2834
#    📊 Punti attesi dopo rimozione: 2834
#    📊 Rimossi effettivamente: 0
#    📊 Dovevano essere rimossi: 0
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 3: soglia = 1000 min
#    • Punti rimanenti: 2834
#       ❌ Cluster 1: 61 punti, max_mean=302.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 73 punti, max_mean=308.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 67 punti, max_mean=252.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 70 punti, max_mean=264.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 76 punti, max_mean=215.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 73 punti, max_mean=270.1min, overtime=0, RIFIUTATO
#       ✅ Cluster 15: 70 punti, max_mean=392.4min, overtime=0, motivo=mean_range
#       ❌ Cluster 16: 75 punti, max_mean=248.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 71 punti, max_mean=280.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 75 punti, max_mean=233.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 71 punti, max_mean=200.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 64 punti, max_mean=380.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 75 punti, max_mean=245.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 75 punti, max_mean=234.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 77 punti, max_mean=277.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 76 punti, max_mean=264.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 74 punti, max_mean=254.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 77 punti, max_mean=225.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 79 punti, max_mean=212.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 77 punti, max_mean=239.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 77 punti, max_mean=245.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 72 punti, max_mean=220.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 67 punti, max_mean=385.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 81 punti, max_mean=192.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 73 punti, max_mean=245.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 83 punti, max_mean=293.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 81 punti, max_mean=212.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 83 punti, max_mean=233.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 86 punti, max_mean=167.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 86 punti, max_mean=198.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 86 punti, max_mean=154.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 83 punti, max_mean=180.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 14 punti, max_mean=63.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 62 punti, max_mean=302.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 68 punti, max_mean=282.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 72 punti, max_mean=334.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 64 punti, max_mean=264.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 71 punti, max_mean=348.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 69 punti, max_mean=283.4min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/39
#
# 🔍 DIAGNOSTICA ITERAZIONE 3:
#    📊 Punti prima: 2834
#    ✅ Cluster 1: 70 punti
#    📊 Totale punti accettati: 70
#    📊 Location_ID unici accettati: 70
#    📊 Punti dopo rimozione: 2764
#    📊 Punti attesi dopo rimozione: 2764
#    📊 Rimossi effettivamente: 70
#    📊 Dovevano essere rimossi: 70
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 4: soglia = 1100 min
#    • Punti rimanenti: 2764
#       ❌ Cluster 1: 69 punti, max_mean=331.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 80 punti, max_mean=245.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 76 punti, max_mean=272.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 78 punti, max_mean=287.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 85 punti, max_mean=231.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 82 punti, max_mean=285.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 82 punti, max_mean=271.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 80 punti, max_mean=283.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 83 punti, max_mean=228.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 80 punti, max_mean=238.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 84 punti, max_mean=292.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 73 punti, max_mean=380.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 85 punti, max_mean=227.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 87 punti, max_mean=261.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 82 punti, max_mean=248.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 86 punti, max_mean=234.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 87 punti, max_mean=237.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 83 punti, max_mean=249.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 90 punti, max_mean=218.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 90 punti, max_mean=210.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 82 punti, max_mean=257.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 89 punti, max_mean=242.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 75 punti, max_mean=385.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 87 punti, max_mean=220.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 91 punti, max_mean=255.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 93 punti, max_mean=226.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 94 punti, max_mean=170.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 56 punti, max_mean=149.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 70 punti, max_mean=308.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 76 punti, max_mean=285.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 79 punti, max_mean=347.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 72 punti, max_mean=279.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 79 punti, max_mean=377.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 79 punti, max_mean=302.8min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/34
#
# 🔍 DIAGNOSTICA ITERAZIONE 4:
#    📊 Punti prima: 2764
#    📊 Totale punti accettati: 0
#    📊 Location_ID unici accettati: 0
#    📊 Punti dopo rimozione: 2764
#    📊 Punti attesi dopo rimozione: 2764
#    📊 Rimossi effettivamente: 0
#    📊 Dovevano essere rimossi: 0
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 5: soglia = 1200 min
#    • Punti rimanenti: 2764
#       ❌ Cluster 1: 78 punti, max_mean=353.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 87 punti, max_mean=348.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 85 punti, max_mean=280.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 85 punti, max_mean=293.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 93 punti, max_mean=264.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 92 punti, max_mean=296.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 91 punti, max_mean=296.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 89 punti, max_mean=289.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 93 punti, max_mean=248.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 90 punti, max_mean=232.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 93 punti, max_mean=265.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 82 punti, max_mean=380.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 94 punti, max_mean=299.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 95 punti, max_mean=269.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 92 punti, max_mean=252.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 93 punti, max_mean=239.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 97 punti, max_mean=252.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 93 punti, max_mean=241.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 97 punti, max_mean=238.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 96 punti, max_mean=249.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 90 punti, max_mean=278.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 100 punti, max_mean=250.1min, overtime=0, RIFIUTATO
#       ✅ Cluster 3: 84 punti, max_mean=390.0min, overtime=0, motivo=mean_range
#       ❌ Cluster 30: 103 punti, max_mean=185.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 66 punti, max_mean=154.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 78 punti, max_mean=319.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 85 punti, max_mean=297.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 87 punti, max_mean=347.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 81 punti, max_mean=296.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 87 punti, max_mean=380.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 88 punti, max_mean=317.7min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/31
#
# 🔍 DIAGNOSTICA ITERAZIONE 5:
#    📊 Punti prima: 2764
#    ✅ Cluster 1: 84 punti
#    📊 Totale punti accettati: 84
#    📊 Location_ID unici accettati: 84
#    📊 Punti dopo rimozione: 2680
#    📊 Punti attesi dopo rimozione: 2680
#    📊 Rimossi effettivamente: 84
#    📊 Dovevano essere rimossi: 84
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 6: soglia = 1300 min
#    • Punti rimanenti: 2680
#       ❌ Cluster 1: 86 punti, max_mean=375.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 94 punti, max_mean=295.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 94 punti, max_mean=295.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 100 punti, max_mean=305.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 101 punti, max_mean=292.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 100 punti, max_mean=282.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 96 punti, max_mean=295.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 103 punti, max_mean=320.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 99 punti, max_mean=238.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 102 punti, max_mean=287.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 104 punti, max_mean=345.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 91 punti, max_mean=387.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 104 punti, max_mean=305.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 102 punti, max_mean=268.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 101 punti, max_mean=243.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 105 punti, max_mean=245.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 103 punti, max_mean=217.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 102 punti, max_mean=269.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 108 punti, max_mean=268.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 104 punti, max_mean=238.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 29 punti, max_mean=132.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 86 punti, max_mean=366.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 94 punti, max_mean=308.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 93 punti, max_mean=337.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 90 punti, max_mean=306.8min, overtime=0, RIFIUTATO
#       ✅ Cluster 7: 95 punti, max_mean=409.1min, overtime=2, motivo=mean_range
#       ❌ Cluster 8: 97 punti, max_mean=311.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 97 punti, max_mean=355.1min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/28
#
# 🔍 DIAGNOSTICA ITERAZIONE 6:
#    📊 Punti prima: 2680
#    ✅ Cluster 1: 95 punti
#    📊 Totale punti accettati: 95
#    📊 Location_ID unici accettati: 95
#    📊 Punti dopo rimozione: 2585
#    📊 Punti attesi dopo rimozione: 2585
#    📊 Rimossi effettivamente: 95
#    📊 Dovevano essere rimossi: 95
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 7: soglia = 1400 min
#    • Punti rimanenti: 2585
#       ✅ Cluster 1: 94 punti, max_mean=394.0min, overtime=1, motivo=mean_range
#       ❌ Cluster 10: 101 punti, max_mean=295.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 112 punti, max_mean=338.3min, overtime=0, RIFIUTATO
#       ✅ Cluster 12: 110 punti, max_mean=300.2min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 13: 109 punti, max_mean=296.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 104 punti, max_mean=297.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 112 punti, max_mean=320.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 105 punti, max_mean=281.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 111 punti, max_mean=345.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 113 punti, max_mean=279.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 104 punti, max_mean=312.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 99 punti, max_mean=387.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 110 punti, max_mean=261.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 112 punti, max_mean=278.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 115 punti, max_mean=241.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 116 punti, max_mean=274.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 107 punti, max_mean=211.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 40 punti, max_mean=176.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 93 punti, max_mean=369.8min, overtime=0, RIFIUTATO
#       ✅ Cluster 4: 102 punti, max_mean=335.9min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 5: 101 punti, max_mean=388.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 99 punti, max_mean=327.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 106 punti, max_mean=343.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 107 punti, max_mean=357.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 103 punti, max_mean=314.4min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 3/25
#
# 🔍 DIAGNOSTICA ITERAZIONE 7:
#    📊 Punti prima: 2585
#    ✅ Cluster 1: 94 punti
#    ✅ Cluster 2: 110 punti
#    ✅ Cluster 3: 102 punti
#    📊 Totale punti accettati: 306
#    📊 Location_ID unici accettati: 306
#    📊 Punti dopo rimozione: 2279
#    📊 Punti attesi dopo rimozione: 2279
#    📊 Rimossi effettivamente: 306
#    📊 Dovevano essere rimossi: 306
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 8: soglia = 1500 min
#    • Punti rimanenti: 2279
#       ❌ Cluster 1: 107 punti, max_mean=387.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 112 punti, max_mean=303.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 121 punti, max_mean=335.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 114 punti, max_mean=299.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 119 punti, max_mean=346.4min, overtime=0, RIFIUTATO
#       ✅ Cluster 14: 121 punti, max_mean=366.1min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 15: 122 punti, max_mean=294.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 115 punti, max_mean=302.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 120 punti, max_mean=262.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 122 punti, max_mean=283.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 122 punti, max_mean=281.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 102 punti, max_mean=374.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 90 punti, max_mean=262.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 109 punti, max_mean=352.4min, overtime=0, RIFIUTATO
#       ✅ Cluster 4: 108 punti, max_mean=354.5min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 5: 115 punti, max_mean=344.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 112 punti, max_mean=336.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 110 punti, max_mean=354.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 121 punti, max_mean=350.2min, overtime=0, RIFIUTATO
#       ✅ Cluster 9: 117 punti, max_mean=352.9min, overtime=1, motivo=overtime_ok
#    ✅ Cluster accettati: 3/20
#
# 🔍 DIAGNOSTICA ITERAZIONE 8:
#    📊 Punti prima: 2279
#    ✅ Cluster 1: 121 punti
#    ✅ Cluster 2: 108 punti
#    ✅ Cluster 3: 117 punti
#    📊 Totale punti accettati: 346
#    📊 Location_ID unici accettati: 346
#    📊 Punti dopo rimozione: 1933
#    📊 Punti attesi dopo rimozione: 1933
#    📊 Rimossi effettivamente: 346
#    📊 Dovevano essere rimossi: 346
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 9: soglia = 1600 min
#    • Punti rimanenti: 1933
#       ✅ Cluster 1: 116 punti, max_mean=418.8min, overtime=0, motivo=mean_range
#       ❌ Cluster 10: 123 punti, max_mean=324.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 126 punti, max_mean=345.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 131 punti, max_mean=310.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 123 punti, max_mean=287.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 127 punti, max_mean=276.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 129 punti, max_mean=309.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 88 punti, max_mean=256.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 110 punti, max_mean=384.4min, overtime=0, RIFIUTATO
#       ✅ Cluster 3: 117 punti, max_mean=394.8min, overtime=0, motivo=mean_range
#       ❌ Cluster 4: 124 punti, max_mean=368.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 121 punti, max_mean=345.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 119 punti, max_mean=384.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 130 punti, max_mean=366.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 120 punti, max_mean=319.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 129 punti, max_mean=343.2min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 2/16
#
# 🔍 DIAGNOSTICA ITERAZIONE 9:
#    📊 Punti prima: 1933
#    ✅ Cluster 1: 116 punti
#    ✅ Cluster 2: 117 punti
#    📊 Totale punti accettati: 233
#    📊 Location_ID unici accettati: 233
#    📊 Punti dopo rimozione: 1700
#    📊 Punti attesi dopo rimozione: 1700
#    📊 Rimossi effettivamente: 233
#    📊 Dovevano essere rimossi: 233
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 10: soglia = 1700 min
#    • Punti rimanenti: 1700
#       ✅ Cluster 1: 119 punti, max_mean=403.2min, overtime=0, motivo=mean_range
#       ❌ Cluster 10: 140 punti, max_mean=316.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 128 punti, max_mean=311.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 139 punti, max_mean=297.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 119 punti, max_mean=341.9min, overtime=0, RIFIUTATO
#       ✅ Cluster 2: 133 punti, max_mean=388.8min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 3: 130 punti, max_mean=356.2min, overtime=0, RIFIUTATO
#       ✅ Cluster 4: 128 punti, max_mean=398.3min, overtime=1, motivo=mean_range
#       ❌ Cluster 5: 136 punti, max_mean=307.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 127 punti, max_mean=325.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 136 punti, max_mean=349.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 131 punti, max_mean=327.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 134 punti, max_mean=363.8min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 3/13
#
# 🔍 DIAGNOSTICA ITERAZIONE 10:
#    📊 Punti prima: 1700
#    ✅ Cluster 1: 119 punti
#    ✅ Cluster 2: 133 punti
#    ✅ Cluster 3: 128 punti
#    📊 Totale punti accettati: 380
#    📊 Location_ID unici accettati: 380
#    📊 Punti dopo rimozione: 1320
#    📊 Punti attesi dopo rimozione: 1320
#    📊 Rimossi effettivamente: 380
#    📊 Dovevano essere rimossi: 380
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 11: soglia = 1800 min
#    • Punti rimanenti: 1320
#       ❌ Cluster 1: 139 punti, max_mean=378.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 42 punti, max_mean=175.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 145 punti, max_mean=317.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 136 punti, max_mean=326.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 145 punti, max_mean=370.4min, overtime=0, RIFIUTATO
#       ✅ Cluster 5: 140 punti, max_mean=376.1min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 6: 144 punti, max_mean=376.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 149 punti, max_mean=301.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 137 punti, max_mean=359.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 143 punti, max_mean=378.3min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/10
#
# 🔍 DIAGNOSTICA ITERAZIONE 11:
#    📊 Punti prima: 1320
#    ✅ Cluster 1: 140 punti
#    📊 Totale punti accettati: 140
#    📊 Location_ID unici accettati: 140
#    📊 Punti dopo rimozione: 1180
#    📊 Punti attesi dopo rimozione: 1180
#    📊 Rimossi effettivamente: 140
#    📊 Dovevano essere rimossi: 140
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 12: soglia = 1900 min
#    • Punti rimanenti: 1180
#       ✅ Cluster 1: 148 punti, max_mean=394.8min, overtime=1, motivo=mean_range
#       ✅ Cluster 2: 154 punti, max_mean=329.2min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 3: 145 punti, max_mean=329.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 153 punti, max_mean=371.8min, overtime=0, RIFIUTATO
#       ✅ Cluster 5: 153 punti, max_mean=393.8min, overtime=2, motivo=mean_range
#       ❌ Cluster 6: 158 punti, max_mean=334.1min, overtime=0, RIFIUTATO
#       ✅ Cluster 7: 147 punti, max_mean=360.9min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 8: 122 punti, max_mean=321.2min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 4/8
#
# 🔍 DIAGNOSTICA ITERAZIONE 12:
#    📊 Punti prima: 1180
#    ✅ Cluster 1: 148 punti
#    ✅ Cluster 2: 154 punti
#    ✅ Cluster 3: 153 punti
#    ✅ Cluster 4: 147 punti
#    📊 Totale punti accettati: 602
#    📊 Location_ID unici accettati: 602
#    📊 Punti dopo rimozione: 578
#    📊 Punti attesi dopo rimozione: 578
#    📊 Rimossi effettivamente: 602
#    📊 Dovevano essere rimossi: 602
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 13: soglia = 2000 min
#    • Punti rimanenti: 578
#       ❌ Cluster 1: 152 punti, max_mean=354.5min, overtime=0, RIFIUTATO
#       ✅ Cluster 2: 161 punti, max_mean=382.0min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 3: 165 punti, max_mean=344.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 100 punti, max_mean=299.6min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/4
#
# 🔍 DIAGNOSTICA ITERAZIONE 13:
#    📊 Punti prima: 578
#    ✅ Cluster 1: 161 punti
#    📊 Totale punti accettati: 161
#    📊 Location_ID unici accettati: 161
#    📊 Punti dopo rimozione: 417
#    📊 Punti attesi dopo rimozione: 417
#    📊 Rimossi effettivamente: 161
#    📊 Dovevano essere rimossi: 161
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 14: soglia = 2100 min
#    • Punti rimanenti: 417
#       ❌ Cluster 1: 160 punti, max_mean=369.0min, overtime=0, RIFIUTATO
#       ✅ Cluster 2: 173 punti, max_mean=394.6min, overtime=2, motivo=mean_range
#       ❌ Cluster 3: 84 punti, max_mean=275.2min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/3
#
# 🔍 DIAGNOSTICA ITERAZIONE 14:
#    📊 Punti prima: 417
#    ✅ Cluster 1: 173 punti
#    📊 Totale punti accettati: 173
#    📊 Location_ID unici accettati: 173
#    📊 Punti dopo rimozione: 244
#    📊 Punti attesi dopo rimozione: 244
#    📊 Rimossi effettivamente: 173
#    📊 Dovevano essere rimossi: 173
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 15: soglia = 2200 min
#    • Punti rimanenti: 244
#       ✅ Cluster 1: 167 punti, max_mean=372.1min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 2: 77 punti, max_mean=272.9min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/2
#
# 🔍 DIAGNOSTICA ITERAZIONE 15:
#    📊 Punti prima: 244
#    ✅ Cluster 1: 167 punti
#    📊 Totale punti accettati: 167
#    📊 Location_ID unici accettati: 167
#    📊 Punti dopo rimozione: 77
#    📊 Punti attesi dopo rimozione: 77
#    📊 Rimossi effettivamente: 167
#    📊 Dovevano essere rimossi: 167
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔧 Assemblaggio soluzione finale...
#    📋 Punti non assegnati: 77
#    🔍 Recuperando cluster rifiutati dall'ultima iterazione...
#    🔍 Recuperando cluster rifiutati dall'ultima iterazione (15)
#    📋 Cluster rifiutati disponibili: 1
#    ✅ Cluster recuperati dopo filtro: 1 (77 punti)
#
# 📊 Calcolando performance finali per 26 cluster...
#
# 🏁 COMPLETATO:
#    • Iterazioni eseguite: 15
#    • Cluster finali totali: 26
#    • Punti totali assegnati: 2972
#    • Copertura: 2972/2972 punti
#
# 📊 Cluster con più di 1 giorno overtime: 4
# Tempo di esecuzione algoritmo: 64.86 min
#
# ✅ NESSUN REFINEMENT necessario - soluzione ottimale trovata

# %%
final_performance.to_csv('clustering_methods_performances/euristic_complete_v2_AS_5.csv')

with open('cluster_dicts/cluster_dict_euristic_complete_v2_AS_5.pkl', 'wb') as f:
    pickle.dump(final_clusters, f)

# %% [markdown]
# # 2 ON

# %%
def clustering_euristico_multicluster(full_time_mat_min: np.ndarray,
                                      index_to_location_id: list[int],
                                      delivery_points: pd.DataFrame,
                                      max_time: int = 500,
                                      unloading_time: int = 10):
    """
    Algoritmo Cluster‐First, Route‐Second:
    • seed = punto più distante dal deposito
    • greedy: aggiunge il punto che allunga meno il tour
    • stop quando supererebbe max_time
    """
    n_points = full_time_mat_min.shape[0]
    unassigned = set(range(1, n_points))          # deposito è indice 0
    clusters = []


    while unassigned:
        # --- nuovo cluster
        first_idx = max(unassigned, key=lambda i: full_time_mat_min[0, i])
        cluster = [first_idx]
        unassigned.remove(first_idx)
        cluster_time = full_time_mat_min[0, first_idx] * 2 + unloading_time


        # --- inserimento greedy
        while unassigned:
            # tempo minimo dal cluster al candidato
            cand, min_cost = min(
                ((c, min(full_time_mat_min[p, c] for p in cluster)) for c in unassigned),
                key=lambda x: x[1]
            )
            if cluster_time + min_cost + unloading_time > max_time:
                break
            cluster.append(cand)
            unassigned.remove(cand)
            cluster_time += min_cost + unloading_time


        clusters.append([index_to_location_id[i] for i in cluster])


    return clusters



def plot_clusters(clusters, delivery_points, title):
    """Visual plot rapido"""
    cmap = plt.cm.get_cmap("tab20", len(clusters))
    plt.figure(figsize=(10, 7))
    for i, cl in enumerate(clusters):
        sub = delivery_points[delivery_points["location_id"].isin(cl)]
        plt.scatter(sub["lon"], sub["lat"], c=[cmap(i)],
                    label=f"C{i+1}", alpha=.7, s=20, edgecolors="k")
    plt.title(title)
    plt.xlabel("lon"); plt.ylabel("lat")
    plt.legend(ncol=2, fontsize="small")
    plt.show()


def deduplicate_clusters(clusters, already_assigned_points):
    """
    Rimuove punti già assegnati dai cluster e restituisce solo cluster validi
    
    Args:
        clusters: lista di cluster (liste di location_id)
        already_assigned_points: set di location_id già assegnati
        
    Returns:
        result: lista di cluster puliti
        assigned: set aggiornato di punti assegnati
    """
    assigned = set(already_assigned_points)
    result = []
    
    for cluster in clusters:
        clean_cluster = [loc_id for loc_id in cluster if loc_id not in assigned]
        if clean_cluster:  # Solo se il cluster ha almeno un punto
            result.append(clean_cluster)
            assigned.update(clean_cluster)
    
    return result, assigned


def get_last_iteration_rejected_clusters(all_results, already_assigned_points, verbose=True):
    """
    Recupera i cluster RIFIUTATI dell'ULTIMA iterazione, filtrando i punti già assegnati
    
    Args:
        all_results: dizionario con i risultati di tutte le iterazioni
        already_assigned_points: set di location_id già assegnati
        verbose: stampa messaggi di debug
        
    Returns:
        lista di cluster filtrati
    """
    if not all_results:
        return []
    
    # Prendi l'ultima iterazione
    last_iteration = max(all_results.keys())
    last_results = all_results[last_iteration]
    
    # Recupera i cluster rifiutati
    rejected_cluster_indices = last_results['rejected_indices']
    all_clusters = last_results['clusters']
    rejected_clusters = [all_clusters[i] for i in rejected_cluster_indices]
    
    if verbose:
        print(f"   🔍 Recuperando cluster rifiutati dall'ultima iterazione ({last_iteration})")
        print(f"   📋 Cluster rifiutati disponibili: {len(rejected_clusters)}")
    
    # Filtra punti già assegnati
    filtered_clusters, _ = deduplicate_clusters(rejected_clusters, already_assigned_points)
    
    if verbose:
        total_points = sum(len(cl) for cl in filtered_clusters)
        print(f"   ✅ Cluster recuperati dopo filtro: {len(filtered_clusters)} ({total_points} punti)")
    
    return filtered_clusters


def count_clusters_with_excessive_overtime(performance_df, threshold=1):
    """
    Conta quanti cluster hanno più di 'threshold' giorni di overtime
    
    Args:
        performance_df: DataFrame con le performance dei cluster
        threshold: soglia di overtime (default 1)
        
    Returns:
        numero di cluster con overtime > threshold
    """
    count = 0
    for cluster_name, cluster_data in performance_df.groupby('cluster'):
        total_overtime = cluster_data['n_overtime_days'].sum()
        if total_overtime > threshold:
            count += 1
    return count



def evaluate_and_accept_clusters(clusters, performance_df, verbose=True):
    """
    Valuta i cluster e decide quali accettare basandosi sui criteri:
    1) Media giornaliera tra 390-480 minuti
    2) Overtime accettabile (massimo 1 giorno per tipo di giorno della settimana)
    
    Returns:
        accepted_clusters: list di cluster (liste di location_id) accettati
        rejected_indices: list di indici dei cluster rifiutati
    """
    accepted_clusters = []
    rejected_indices = []
    
    # Raggruppa performance per cluster
    for cluster_name, cluster_data in performance_df.groupby('cluster'):
        cluster_index = int(cluster_name.split()[-1]) - 1  # "Cluster 1" -> index 0
        cluster = clusters[cluster_index]
        
        # CRITERIO 1: Media giornaliera tra 390-480 minuti
        mean_minutes_range = cluster_data['mean_minutes'].between(390, 480).any()
        
        # CRITERIO 2: Overtime accettabile
        overtime_acceptable = check_overtime_acceptable(cluster_data)
        
        if mean_minutes_range or overtime_acceptable:
            accepted_clusters.append(cluster)
            if verbose:
                max_mean = cluster_data['mean_minutes'].max()
                total_overtime = cluster_data['n_overtime_days'].sum()
                reason = "mean_range" if mean_minutes_range else "overtime_ok"
                print(f"      ✅ {cluster_name}: {len(cluster)} punti, "
                      f"max_mean={max_mean:.1f}min, overtime={total_overtime}, "
                      f"motivo={reason}")
        else:
            rejected_indices.append(cluster_index)
            if verbose:
                max_mean = cluster_data['mean_minutes'].max()
                total_overtime = cluster_data['n_overtime_days'].sum()
                print(f"      ❌ {cluster_name}: {len(cluster)} punti, "
                      f"max_mean={max_mean:.1f}min, overtime={total_overtime}, "
                      f"RIFIUTATO")
    
    return accepted_clusters, rejected_indices



def check_overtime_acceptable(cluster_data):
    """
    Controlla se l'overtime è accettabile:
    massimo 1 giorno di overtime per ogni giorno della settimana
    
    Args:
        cluster_data: DataFrame con performance di un singolo cluster
    
    Returns:
        bool: True se overtime accettabile, False altrimenti
    """
    # Controlla per ogni giorno della settimana
    for _, row in cluster_data.iterrows():
        if row['n_overtime_days'] > 1:  # Più di 1 giorno di overtime per questo weekday -> non accettato
            return False
        elif row['n_overtime_days'] == 1:
            return True  # Ok, 1 giorno di overtime è accettabile
    
    return False






def assemble_final_performance_from_cache(all_results, final_complete_clusters, verbose=True):
    """
    Assembla un DataFrame finale dalle performance già calcolate nelle iterazioni.
    Molto più veloce del ricalcolo completo.
    """
    if verbose:
        print("📋 Assemblando performance finali da cache esistenti...")
    
    final_performance_pieces = []
    cluster_counter = 1
    
    for cluster in final_complete_clusters:
        cluster_found = False
        
        # Cerca questo cluster nelle iterazioni passate
        for iteration_num, results in all_results.items():
            for i, iter_cluster in enumerate(results['clusters']):
                if set(iter_cluster) == set(cluster):  # Stesso cluster
                    # Prendi le performance già calcolate
                    iter_perf_df = results['performance_df']
                    cluster_name_old = f"Cluster {i+1}"
                    cluster_data = iter_perf_df[iter_perf_df['cluster'] == cluster_name_old].copy()
                    
                    # Rinomina con il nuovo indice
                    cluster_data['cluster'] = f"Cluster {cluster_counter}"
                    final_performance_pieces.append(cluster_data)
                    cluster_counter += 1
                    cluster_found = True
                    break
            
            if cluster_found:
                break
        
        if not cluster_found and verbose:
            print(f"   ⚠️ Cluster non trovato in cache - dovrà essere ricalcolato")
    
    if final_performance_pieces:
        final_df = pd.concat(final_performance_pieces, ignore_index=True)
        if verbose:
            print(f"   ✅ Assemblate performance per {len(final_performance_pieces)} cluster da cache")
        return final_df
    else:
        if verbose:
            print("   ⚠️ Nessuna performance in cache - calcolo completo necessario")
        return None



def heuristic_iterative_clustering_complete(delivery_points: pd.DataFrame,
                                           depot_location: tuple[float, float],
                                           initial_threshold: int = 800,
                                           increment_threshold: int = 120,
                                           unload_min: int = 10,
                                           max_iterations: int = 10,
                                           verbose: bool = True,
                                           enable_diagnostics: bool = False):
    """
    Algoritmo iterativo che restituisce TUTTI i punti assegnati a cluster.
    MODIFICHE:
    - Ogni punto assegnato ad un solo cluster (no duplicati)
    - Fallback all'ultima iterazione per punti non assegnati
    - Refinement automatico se >5 cluster con overtime >1
    
    Returns:
        all_results: dict con tutti i risultati intermedi
        final_complete_clusters: list di TUTTI i cluster (accettati + migliori fallback)
        final_performance: DataFrame con performance di tutti i cluster finali
        refinement_applied: bool indicante se è stato applicato refinement
    """
    
    if verbose:
        print("🔄 INIZIO clustering iterativo COMPLETO con soglia crescente")
        print(f"   • Soglia iniziale: {initial_threshold} min")
        print(f"   • Incremento: +{increment_threshold} min per iterazione")
    
    all_results = {}
    remaining_points = delivery_points.copy()
    original_points = set(delivery_points['location_id'])
    already_assigned_points = set()  # NUOVO: Traccia globale dei punti già assegnati
    current_threshold = initial_threshold
    
    for iteration in range(max_iterations):
        if verbose:
            print(f"\n🔄 Iterazione {iteration + 1}: soglia = {current_threshold} min")
            print(f"   • Punti rimanenti: {len(remaining_points)}")
        
        if remaining_points.empty:
            if verbose:
                print("   ✅ Nessun punto rimanente - STOP")
            break
        
        # ================== CLUSTERING ==================
        dm, tm, idx2loc, _ = pc.distance_matrix_creation('', remaining_points)
        clusters = clustering_euristico_multicluster(
            tm, idx2loc, remaining_points,
            max_time=current_threshold,
            unloading_time=unload_min
        )
        
        if not clusters:
            if verbose:
                print("   ⚠️ Nessun cluster generato - STOP")
            break
        
        # ================== PERFORMANCE ==================
        performance_df = pc.calc_clusters_stats_ON(
            clusters, time_limit=3, parallel=True, max_workers=7, verbose=False
        )
        
        # ================== VALUTAZIONE E ACCETTAZIONE ==================
        accepted_clusters, rejected_cluster_indices = evaluate_and_accept_clusters(
            clusters, performance_df, verbose=verbose
        )
        
        # Salva risultati dell'iterazione (con rejected_indices invece di rejected_clusters)
        all_results[iteration + 1] = {
            'threshold': current_threshold,
            'clusters': clusters,
            'performance_df': performance_df,
            'accepted_clusters': accepted_clusters,
            'rejected_indices': rejected_cluster_indices
        }
        
        if verbose:
            print(f"   ✅ Cluster accettati: {len(accepted_clusters)}/{len(clusters)}")
        
        # ================== RIMOZIONE PUNTI ACCETTATI (NO DUPLICATI) ==================
        accepted_location_ids = set()
        for cluster in accepted_clusters:
            accepted_location_ids.update(cluster)
        
        # NUOVO: Filtra solo gli ID che esistono effettivamente nel DataFrame
        existing_ids = set(remaining_points['location_id'])
        valid_accepted_ids = accepted_location_ids.intersection(existing_ids)
        missing_ids = accepted_location_ids - existing_ids
        
        if verbose and missing_ids:
            print(f'   ⚠️ ID nei cluster ma non nel DataFrame: {len(missing_ids)} ID')
            print(f'   🔧 ID validi da rimuovere: {len(valid_accepted_ids)} ID')
        
        # NUOVO: Aggiorna il set globale dei punti assegnati
        already_assigned_points.update(valid_accepted_ids)

        # PER LA DIAGNOSTICA (opzionale):
        if enable_diagnostics and verbose:
            remaining_points_after_removal = remaining_points[
                ~remaining_points["location_id"].isin(valid_accepted_ids)
            ].copy()
            diagnose_point_removal(remaining_points, accepted_clusters, 
                remaining_points_after_removal, iteration + 1)
        
        # USA VALID_ACCEPTED_IDS invece di ACCEPTED_LOCATION_IDS
        remaining_points = remaining_points[
            ~remaining_points['location_id'].isin(valid_accepted_ids)
        ].copy()
        
        # Se tutti i cluster sono stati accettati, abbiamo finito
        if len(accepted_clusters) == len(clusters):
            if verbose:
                print("   🎯 Tutti i cluster sono stati accettati - STOP")
            break
        
        # Incrementa soglia per prossima iterazione
        current_threshold += increment_threshold
    
    # ================== ASSEMBLAGGIO FINALE ==================
    if verbose:
        print(f"\n🔧 Assemblaggio soluzione finale...")
    
    final_complete_clusters = []
    
    # 1. Aggiungi tutti i cluster accettati (già senza duplicati)
    for iteration_results in all_results.values():
        for cluster in iteration_results['accepted_clusters']:
            final_complete_clusters.append(cluster)
    
    # 2. NUOVO: Per i punti rimanenti, usa i cluster RIFIUTATI dell'ULTIMA ITERAZIONE
    unassigned_points = original_points - already_assigned_points
    
    if unassigned_points:
        if verbose:
            print(f"   📋 Punti non assegnati: {len(unassigned_points)}")
            print("   🔍 Recuperando cluster rifiutati dall'ultima iterazione...")
        
        last_iteration_clusters = get_last_iteration_rejected_clusters(
            all_results, already_assigned_points, verbose
        )
        
        final_complete_clusters.extend(last_iteration_clusters)
        for cluster in last_iteration_clusters:
            already_assigned_points.update(cluster)
    
    # ================== PERFORMANCE FINALI ==================
    if verbose:
        print(f"\n📊 Calcolando performance finali per {len(final_complete_clusters)} cluster...")
    
    # Calcola performance (senza cache per ora, per evitare problemi)
    final_performance = pc.calc_clusters_stats_ON(
        final_complete_clusters, time_limit=3, parallel=True, max_workers=7, verbose=False
    )
    
    if verbose:
        total_points = sum(len(cluster) for cluster in final_complete_clusters)
        print(f"\n🏁 COMPLETATO:")
        print(f"   • Iterazioni eseguite: {len(all_results)}")
        print(f"   • Cluster finali totali: {len(final_complete_clusters)}")
        print(f"   • Punti totali assegnati: {total_points}")
        print(f"   • Copertura: {total_points}/{len(original_points)} punti")
        
        missing = len(original_points) - total_points
        if missing > 0:
            print(f"   ⚠️ Punti mancanti: {missing}")
    
    # ================== CHECK OVERTIME ECCESSIVO E REFINEMENT ==================
    excessive_overtime_count = count_clusters_with_excessive_overtime(final_performance, threshold=1)
    
    if verbose:
        print(f"\n📊 Cluster con più di 1 giorno overtime: {excessive_overtime_count}")
    
    # NUOVO: Se ci sono più di 5 cluster con overtime eccessivo, applica refinement
    refinement_needed = excessive_overtime_count > 5
    
    if refinement_needed:
        if verbose:
            print(f"\n🔄 REFINEMENT NECESSARIO: {excessive_overtime_count} cluster con overtime > 1")
            print("   🚀 Avvio 5 cicli aggiuntivi con soglia 1550 min (+60/iterazione)...")
        
        # Identifica i punti nei cluster problematici
        problematic_points = set()
        problematic_cluster_names = []
        for cluster_name, cluster_data in final_performance.groupby('cluster'):
            total_overtime = cluster_data['n_overtime_days'].sum()
            if total_overtime > 1:
                problematic_cluster_names.append(cluster_name)
                cluster_index = int(cluster_name.split()[-1]) - 1
                problematic_cluster = final_complete_clusters[cluster_index]
                problematic_points.update(problematic_cluster)
        
        # Crea DataFrame con i punti problematici
        refinement_points = delivery_points[
            delivery_points['location_id'].isin(problematic_points)
        ].copy()
        
        if verbose:
            print(f"   📋 Cluster problematici: {len(problematic_cluster_names)}")
            print(f"   📋 Punti da riclusterare: {len(refinement_points)}")
        
        # Applica refinement (ricorsivo)
        refinement_results, refinement_clusters, refinement_performance, _ = heuristic_iterative_clustering_complete(
            delivery_points=refinement_points,
            depot_location=depot_location,
            initial_threshold=1550,  # NUOVO: soglia più alta
            increment_threshold=60,   # NUOVO: incremento più piccolo
            unload_min=unload_min,
            max_iterations=5,        # NUOVO: max 5 iterazioni
            verbose=verbose,
            enable_diagnostics=False  # Disabilita diagnostica nel refinement
        )
        
        # Sostituisci i cluster problematici con quelli raffinati
        final_complete_clusters = [
            cl for cl in final_complete_clusters 
            if not any(p in problematic_points for p in cl)
        ]
        final_complete_clusters.extend(refinement_clusters)
        
        # Ricalcola performance finali
        final_performance = pc.calc_clusters_stats_ON(
            final_complete_clusters, time_limit=3, parallel=True, max_workers=7, verbose=False
        )
        
        if verbose:
            print(f"\n✅ REFINEMENT COMPLETATO")
            print(f"   • Nuovi cluster totali: {len(final_complete_clusters)}")
            excessive_after = count_clusters_with_excessive_overtime(final_performance, threshold=1)
            print(f"   • Cluster con overtime > 1: {excessive_after} (prima: {excessive_overtime_count})")
        
        return all_results, final_complete_clusters, final_performance, True
    
    return all_results, final_complete_clusters, final_performance, False





def plot_iteration_results(all_results, delivery_points, iteration_to_plot=None):
    """
    Plotta i risultati di una specifica iterazione o dell'ultima
    """
    if iteration_to_plot is None:
        iteration_to_plot = max(all_results.keys())
    
    if iteration_to_plot not in all_results:
        print(f"Iterazione {iteration_to_plot} non trovata")
        return
    
    results = all_results[iteration_to_plot]
    clusters = results['clusters']
    threshold = results['threshold']
    accepted = results['accepted_clusters']
    
    plot_clusters(clusters, delivery_points, 
                  f"Iterazione {iteration_to_plot} - Soglia {threshold} min "
                  f"({len(accepted)} accettati/{len(clusters)} totali)")



# ------------------------------------------------
# ----------------------------------------------------------------------------------------
# SOLO PER DEBUG
# ----------------------------------------------------------------------------------------
# ------------------------------------------------


def diagnose_point_removal(remaining_points_before, accepted_clusters, remaining_points_after, iteration):
    """Diagnostica dettagliata per capire la discrepanza"""
    
    print(f"\n🔍 DIAGNOSTICA ITERAZIONE {iteration}:")
    
    # 1. Conta punti prima
    points_before = len(remaining_points_before)
    print(f"   📊 Punti prima: {points_before}")
    
    # 2. Conta punti negli cluster accettati
    accepted_location_ids = set()
    total_accepted_points = 0
    for i, cluster in enumerate(accepted_clusters):
        cluster_size = len(cluster)
        total_accepted_points += cluster_size
        accepted_location_ids.update(cluster)
        print(f"   ✅ Cluster {i+1}: {cluster_size} punti")
    
    print(f"   📊 Totale punti accettati: {total_accepted_points}")
    print(f"   📊 Location_ID unici accettati: {len(accepted_location_ids)}")
    
    # 3. Verifica che tutti i location_id accettati esistano in remaining_points_before
    existing_ids = set(remaining_points_before['location_id'])
    missing_ids = accepted_location_ids - existing_ids
    if missing_ids:
        print(f"   ⚠️ PROBLEMA: {len(missing_ids)} ID accettati non esistono in remaining_points!")
        print(f"      ID mancanti: {list(missing_ids)[:10]}...")
    
    # 4. Simula la rimozione manualmente
    should_remain = remaining_points_before[
        ~remaining_points_before['location_id'].isin(accepted_location_ids)
    ]
    expected_remaining = len(should_remain)
    
    # 5. Conta punti dopo
    points_after = len(remaining_points_after)
    print(f"   📊 Punti dopo rimozione: {points_after}")
    print(f"   📊 Punti attesi dopo rimozione: {expected_remaining}")
    
    # 6. Calcola discrepanze
    actual_removed = points_before - points_after
    expected_removed = len(accepted_location_ids)
    discrepancy = total_accepted_points - actual_removed
    
    print(f"   📊 Rimossi effettivamente: {actual_removed}")
    print(f"   📊 Dovevano essere rimossi: {expected_removed}")
    print(f"   📊 DISCREPANZA: {discrepancy}")
    
    if discrepancy != 0:
        print(f"   ❌ DISCREPANZA RILEVATA!")
        
        # Analisi più profonda
        if points_after != expected_remaining:
            print(f"   🔍 Il DataFrame finale non corrisponde alla simulazione")
            print(f"   🔍 Differenza: {points_after - expected_remaining}")
    
    print(f"   ✅ Diagnostica completata\n")
    
    return {
        'points_before': points_before,
        'total_accepted_points': total_accepted_points,
        'actual_removed': actual_removed,
        'discrepancy': discrepancy
    }

# ------------------------------------------------
# ----------------------------------------------------------------------------------------
# FINE DEBUG
# ----------------------------------------------------------------------------------------
# ------------------------------------------------

# %%
import time
start = time.time()

all_results, final_clusters, final_performance, refinement_applied = heuristic_iterative_clustering_complete(
    delivery_points=pc.delivery_points_ON,
    depot_location=pc.depot_location,
    initial_threshold=800,
    increment_threshold=100,
    unload_min=10,
    max_iterations=15,
    verbose=True,
    enable_diagnostics=True  # Metti False per disabilitare la diagnostica
)


end = time.time()
print(f"Tempo di esecuzione algoritmo: {(end - start)/60:.2f} min")

# Stampa risultato refinement
if refinement_applied:
    print("\n🎯 REFINEMENT APPLICATO con successo!")
else:
    print("\n✅ NESSUN REFINEMENT necessario - soluzione ottimale trovata")
# Out:
# 🔄 INIZIO clustering iterativo COMPLETO con soglia crescente
#    • Soglia iniziale: 800 min
#    • Incremento: +100 min per iterazione
#
# 🔄 Iterazione 1: soglia = 800 min
#    • Punti rimanenti: 3219
#       ✅ Cluster 1: 40 punti, max_mean=395.2min, overtime=0, motivo=mean_range
#       ❌ Cluster 10: 53 punti, max_mean=277.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 54 punti, max_mean=305.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 57 punti, max_mean=300.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 55 punti, max_mean=222.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 54 punti, max_mean=236.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 50 punti, max_mean=232.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 53 punti, max_mean=313.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 56 punti, max_mean=236.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 54 punti, max_mean=292.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 59 punti, max_mean=338.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 47 punti, max_mean=339.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 58 punti, max_mean=227.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 54 punti, max_mean=317.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 59 punti, max_mean=206.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 58 punti, max_mean=221.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 61 punti, max_mean=328.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 59 punti, max_mean=251.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 60 punti, max_mean=216.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 58 punti, max_mean=275.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 58 punti, max_mean=224.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 57 punti, max_mean=239.6min, overtime=0, RIFIUTATO
#       ✅ Cluster 3: 48 punti, max_mean=409.7min, overtime=0, motivo=mean_range
#       ❌ Cluster 30: 57 punti, max_mean=291.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 60 punti, max_mean=243.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 58 punti, max_mean=318.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 61 punti, max_mean=251.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 56 punti, max_mean=250.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 60 punti, max_mean=267.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 62 punti, max_mean=217.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 57 punti, max_mean=217.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 62 punti, max_mean=227.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 65 punti, max_mean=300.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 49 punti, max_mean=286.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 40: 60 punti, max_mean=253.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 41: 67 punti, max_mean=242.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 42: 68 punti, max_mean=210.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 43: 66 punti, max_mean=233.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 44: 64 punti, max_mean=189.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 45: 65 punti, max_mean=195.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 46: 67 punti, max_mean=256.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 47: 64 punti, max_mean=258.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 48: 67 punti, max_mean=182.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 49: 68 punti, max_mean=197.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 47 punti, max_mean=298.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 50: 64 punti, max_mean=174.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 51: 66 punti, max_mean=188.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 52: 68 punti, max_mean=176.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 53: 68 punti, max_mean=210.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 54: 67 punti, max_mean=153.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 55: 61 punti, max_mean=145.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 56: 9 punti, max_mean=70.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 48 punti, max_mean=311.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 51 punti, max_mean=185.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 53 punti, max_mean=385.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 52 punti, max_mean=294.6min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 2/56
#
# 🔍 DIAGNOSTICA ITERAZIONE 1:
#    📊 Punti prima: 3219
#    ✅ Cluster 1: 40 punti
#    ✅ Cluster 2: 48 punti
#    📊 Totale punti accettati: 88
#    📊 Location_ID unici accettati: 88
#    📊 Punti dopo rimozione: 3131
#    📊 Punti attesi dopo rimozione: 3131
#    📊 Rimossi effettivamente: 88
#    📊 Dovevano essere rimossi: 88
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 2: soglia = 900 min
#    • Punti rimanenti: 3131
#       ❌ Cluster 1: 55 punti, max_mean=343.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 65 punti, max_mean=276.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 64 punti, max_mean=277.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 62 punti, max_mean=263.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 59 punti, max_mean=254.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 60 punti, max_mean=313.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 63 punti, max_mean=241.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 63 punti, max_mean=311.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 66 punti, max_mean=361.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 67 punti, max_mean=257.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 62 punti, max_mean=321.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 57 punti, max_mean=288.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 66 punti, max_mean=234.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 65 punti, max_mean=228.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 68 punti, max_mean=253.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 69 punti, max_mean=238.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 68 punti, max_mean=298.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 67 punti, max_mean=242.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 65 punti, max_mean=276.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 65 punti, max_mean=375.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 67 punti, max_mean=227.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 70 punti, max_mean=257.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 56 punti, max_mean=313.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 71 punti, max_mean=294.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 72 punti, max_mean=310.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 69 punti, max_mean=317.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 70 punti, max_mean=237.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 66 punti, max_mean=279.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 70 punti, max_mean=246.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 73 punti, max_mean=218.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 76 punti, max_mean=279.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 76 punti, max_mean=266.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 76 punti, max_mean=229.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 56 punti, max_mean=339.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 40: 72 punti, max_mean=226.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 41: 77 punti, max_mean=263.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 42: 77 punti, max_mean=203.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 43: 77 punti, max_mean=205.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 44: 74 punti, max_mean=235.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 45: 74 punti, max_mean=188.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 46: 73 punti, max_mean=201.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 47: 57 punti, max_mean=176.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 59 punti, max_mean=192.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 63 punti, max_mean=380.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 59 punti, max_mean=301.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 62 punti, max_mean=374.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 63 punti, max_mean=319.1min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/47
#
# 🔍 DIAGNOSTICA ITERAZIONE 2:
#    📊 Punti prima: 3131
#    📊 Totale punti accettati: 0
#    📊 Location_ID unici accettati: 0
#    📊 Punti dopo rimozione: 3131
#    📊 Punti attesi dopo rimozione: 3131
#    📊 Rimossi effettivamente: 0
#    📊 Dovevano essere rimossi: 0
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 3: soglia = 1000 min
#    • Punti rimanenti: 3131
#       ❌ Cluster 1: 64 punti, max_mean=347.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 72 punti, max_mean=340.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 73 punti, max_mean=320.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 71 punti, max_mean=305.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 68 punti, max_mean=277.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 68 punti, max_mean=314.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 70 punti, max_mean=290.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 72 punti, max_mean=346.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 76 punti, max_mean=264.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 69 punti, max_mean=322.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 74 punti, max_mean=311.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 66 punti, max_mean=291.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 74 punti, max_mean=253.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 76 punti, max_mean=308.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 75 punti, max_mean=336.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 77 punti, max_mean=276.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 77 punti, max_mean=286.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 76 punti, max_mean=267.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 74 punti, max_mean=282.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 73 punti, max_mean=310.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 80 punti, max_mean=251.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 80 punti, max_mean=324.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 65 punti, max_mean=327.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 80 punti, max_mean=316.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 75 punti, max_mean=239.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 78 punti, max_mean=244.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 78 punti, max_mean=284.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 85 punti, max_mean=282.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 82 punti, max_mean=230.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 85 punti, max_mean=252.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 82 punti, max_mean=253.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 84 punti, max_mean=263.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 85 punti, max_mean=190.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 64 punti, max_mean=318.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 40: 85 punti, max_mean=218.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 41: 83 punti, max_mean=219.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 42: 65 punti, max_mean=189.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 68 punti, max_mean=214.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 71 punti, max_mean=378.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 67 punti, max_mean=306.1min, overtime=0, RIFIUTATO
#       ✅ Cluster 8: 72 punti, max_mean=436.3min, overtime=0, motivo=mean_range
#       ❌ Cluster 9: 72 punti, max_mean=322.4min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/42
#
# 🔍 DIAGNOSTICA ITERAZIONE 3:
#    📊 Punti prima: 3131
#    ✅ Cluster 1: 72 punti
#    📊 Totale punti accettati: 72
#    📊 Location_ID unici accettati: 72
#    📊 Punti dopo rimozione: 3059
#    📊 Punti attesi dopo rimozione: 3059
#    📊 Rimossi effettivamente: 72
#    📊 Dovevano essere rimossi: 72
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 4: soglia = 1100 min
#    • Punti rimanenti: 3059
#       ❌ Cluster 1: 73 punti, max_mean=351.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 76 punti, max_mean=323.9min, overtime=0, RIFIUTATO
#       ✅ Cluster 11: 78 punti, max_mean=428.8min, overtime=2, motivo=mean_range
#       ❌ Cluster 12: 79 punti, max_mean=271.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 76 punti, max_mean=290.8min, overtime=0, RIFIUTATO
#       ✅ Cluster 14: 81 punti, max_mean=452.1min, overtime=2, motivo=mean_range
#       ✅ Cluster 15: 81 punti, max_mean=412.2min, overtime=0, motivo=mean_range
#       ❌ Cluster 16: 86 punti, max_mean=295.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 78 punti, max_mean=350.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 83 punti, max_mean=321.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 79 punti, max_mean=261.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 75 punti, max_mean=289.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 84 punti, max_mean=326.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 85 punti, max_mean=293.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 88 punti, max_mean=277.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 86 punti, max_mean=302.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 84 punti, max_mean=270.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 83 punti, max_mean=263.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 90 punti, max_mean=349.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 89 punti, max_mean=304.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 87 punti, max_mean=326.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 89 punti, max_mean=275.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 72 punti, max_mean=332.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 90 punti, max_mean=264.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 94 punti, max_mean=226.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 90 punti, max_mean=340.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 93 punti, max_mean=295.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 94 punti, max_mean=236.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 93 punti, max_mean=238.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 90 punti, max_mean=231.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 79 punti, max_mean=221.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 71 punti, max_mean=347.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 77 punti, max_mean=255.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 77 punti, max_mean=376.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 72 punti, max_mean=311.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 80 punti, max_mean=329.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 77 punti, max_mean=323.0min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 3/37
#
# 🔍 DIAGNOSTICA ITERAZIONE 4:
#    📊 Punti prima: 3059
#    ✅ Cluster 1: 78 punti
#    ✅ Cluster 2: 81 punti
#    ✅ Cluster 3: 81 punti
#    📊 Totale punti accettati: 240
#    📊 Location_ID unici accettati: 240
#    📊 Punti dopo rimozione: 2819
#    📊 Punti attesi dopo rimozione: 2819
#    📊 Rimossi effettivamente: 240
#    📊 Dovevano essere rimossi: 240
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 5: soglia = 1200 min
#    • Punti rimanenti: 2819
#       ❌ Cluster 1: 83 punti, max_mean=363.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 85 punti, max_mean=354.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 90 punti, max_mean=339.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 86 punti, max_mean=302.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 84 punti, max_mean=306.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 94 punti, max_mean=327.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 85 punti, max_mean=363.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 91 punti, max_mean=340.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 87 punti, max_mean=285.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 94 punti, max_mean=343.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 94 punti, max_mean=352.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 82 punti, max_mean=302.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 95 punti, max_mean=326.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 92 punti, max_mean=276.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 95 punti, max_mean=341.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 97 punti, max_mean=327.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 98 punti, max_mean=378.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 99 punti, max_mean=277.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 100 punti, max_mean=293.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 101 punti, max_mean=317.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 104 punti, max_mean=295.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 101 punti, max_mean=306.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 81 punti, max_mean=350.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 102 punti, max_mean=235.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 94 punti, max_mean=229.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 1 punti, max_mean=24.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 79 punti, max_mean=352.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 86 punti, max_mean=277.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 85 punti, max_mean=386.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 81 punti, max_mean=380.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 88 punti, max_mean=350.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 85 punti, max_mean=338.9min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/32
#
# 🔍 DIAGNOSTICA ITERAZIONE 5:
#    📊 Punti prima: 2819
#    📊 Totale punti accettati: 0
#    📊 Location_ID unici accettati: 0
#    📊 Punti dopo rimozione: 2819
#    📊 Punti attesi dopo rimozione: 2819
#    📊 Rimossi effettivamente: 0
#    📊 Dovevano essere rimossi: 0
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 6: soglia = 1300 min
#    • Punti rimanenti: 2819
#       ✅ Cluster 1: 92 punti, max_mean=366.2min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 10: 99 punti, max_mean=375.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 94 punti, max_mean=309.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 92 punti, max_mean=329.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 102 punti, max_mean=358.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 99 punti, max_mean=345.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 94 punti, max_mean=373.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 101 punti, max_mean=372.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 96 punti, max_mean=292.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 103 punti, max_mean=386.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 105 punti, max_mean=340.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 91 punti, max_mean=308.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 101 punti, max_mean=320.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 105 punti, max_mean=341.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 106 punti, max_mean=342.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 105 punti, max_mean=372.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 108 punti, max_mean=282.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 110 punti, max_mean=354.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 111 punti, max_mean=279.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 112 punti, max_mean=282.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 106 punti, max_mean=272.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 44 punti, max_mean=160.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 89 punti, max_mean=363.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 87 punti, max_mean=365.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 95 punti, max_mean=317.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 91 punti, max_mean=387.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 90 punti, max_mean=352.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 97 punti, max_mean=350.1min, overtime=0, RIFIUTATO
#       ✅ Cluster 9: 94 punti, max_mean=389.0min, overtime=1, motivo=overtime_ok
#    ✅ Cluster accettati: 2/29
#
# 🔍 DIAGNOSTICA ITERAZIONE 6:
#    📊 Punti prima: 2819
#    ✅ Cluster 1: 92 punti
#    ✅ Cluster 2: 94 punti
#    📊 Totale punti accettati: 186
#    📊 Location_ID unici accettati: 186
#    📊 Punti dopo rimozione: 2633
#    📊 Punti attesi dopo rimozione: 2633
#    📊 Rimossi effettivamente: 186
#    📊 Dovevano essere rimossi: 186
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 7: soglia = 1400 min
#    • Punti rimanenti: 2633
#       ❌ Cluster 1: 99 punti, max_mean=343.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 101 punti, max_mean=342.0min, overtime=0, RIFIUTATO
#       ✅ Cluster 11: 110 punti, max_mean=422.3min, overtime=1, motivo=mean_range
#       ❌ Cluster 12: 103 punti, max_mean=373.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 111 punti, max_mean=359.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 105 punti, max_mean=344.4min, overtime=0, RIFIUTATO
#       ✅ Cluster 15: 109 punti, max_mean=425.8min, overtime=1, motivo=mean_range
#       ❌ Cluster 16: 113 punti, max_mean=322.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 114 punti, max_mean=334.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 112 punti, max_mean=305.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 115 punti, max_mean=360.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 98 punti, max_mean=366.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 115 punti, max_mean=344.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 117 punti, max_mean=344.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 113 punti, max_mean=368.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 117 punti, max_mean=291.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 117 punti, max_mean=324.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 52 punti, max_mean=177.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 95 punti, max_mean=385.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 104 punti, max_mean=336.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 99 punti, max_mean=380.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 98 punti, max_mean=362.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 106 punti, max_mean=354.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 108 punti, max_mean=385.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 102 punti, max_mean=351.8min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 2/25
#
# 🔍 DIAGNOSTICA ITERAZIONE 7:
#    📊 Punti prima: 2633
#    ✅ Cluster 1: 110 punti
#    ✅ Cluster 2: 109 punti
#    📊 Totale punti accettati: 219
#    📊 Location_ID unici accettati: 219
#    📊 Punti dopo rimozione: 2414
#    📊 Punti attesi dopo rimozione: 2414
#    📊 Rimossi effettivamente: 219
#    📊 Dovevano essere rimossi: 219
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 8: soglia = 1500 min
#    • Punti rimanenti: 2414
#       ❌ Cluster 1: 107 punti, max_mean=349.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 117 punti, max_mean=361.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 110 punti, max_mean=376.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 112 punti, max_mean=377.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 118 punti, max_mean=329.1min, overtime=0, RIFIUTATO
#       ✅ Cluster 14: 111 punti, max_mean=394.2min, overtime=0, motivo=mean_range
#       ❌ Cluster 15: 123 punti, max_mean=379.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 119 punti, max_mean=336.8min, overtime=0, RIFIUTATO
#       ✅ Cluster 17: 123 punti, max_mean=419.6min, overtime=0, motivo=mean_range
#       ❌ Cluster 18: 126 punti, max_mean=320.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 125 punti, max_mean=345.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 106 punti, max_mean=377.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 124 punti, max_mean=304.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 116 punti, max_mean=366.0min, overtime=0, RIFIUTATO
#       ✅ Cluster 3: 104 punti, max_mean=425.2min, overtime=2, motivo=mean_range
#       ❌ Cluster 4: 113 punti, max_mean=356.1min, overtime=0, RIFIUTATO
#       ✅ Cluster 5: 112 punti, max_mean=468.3min, overtime=6, motivo=mean_range
#       ❌ Cluster 6: 115 punti, max_mean=370.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 112 punti, max_mean=388.2min, overtime=0, RIFIUTATO
#       ✅ Cluster 8: 111 punti, max_mean=427.5min, overtime=1, motivo=mean_range
#       ❌ Cluster 9: 110 punti, max_mean=324.8min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 5/21
#
# 🔍 DIAGNOSTICA ITERAZIONE 8:
#    📊 Punti prima: 2414
#    ✅ Cluster 1: 111 punti
#    ✅ Cluster 2: 123 punti
#    ✅ Cluster 3: 104 punti
#    ✅ Cluster 4: 112 punti
#    ✅ Cluster 5: 111 punti
#    📊 Totale punti accettati: 561
#    📊 Location_ID unici accettati: 561
#    📊 Punti dopo rimozione: 1853
#    📊 Punti attesi dopo rimozione: 1853
#    📊 Rimossi effettivamente: 561
#    📊 Dovevano essere rimossi: 561
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 9: soglia = 1600 min
#    • Punti rimanenti: 1853
#       ❌ Cluster 1: 114 punti, max_mean=378.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 128 punti, max_mean=324.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 132 punti, max_mean=387.5min, overtime=0, RIFIUTATO
#       ✅ Cluster 12: 135 punti, max_mean=404.3min, overtime=0, motivo=mean_range
#       ❌ Cluster 13: 136 punti, max_mean=333.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 137 punti, max_mean=308.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 118 punti, max_mean=320.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 113 punti, max_mean=378.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 121 punti, max_mean=374.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 123 punti, max_mean=379.7min, overtime=0, RIFIUTATO
#       ✅ Cluster 5: 121 punti, max_mean=408.3min, overtime=0, motivo=mean_range
#       ✅ Cluster 6: 119 punti, max_mean=406.0min, overtime=0, motivo=mean_range
#       ❌ Cluster 7: 127 punti, max_mean=351.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 117 punti, max_mean=388.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 112 punti, max_mean=373.4min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 3/15
#
# 🔍 DIAGNOSTICA ITERAZIONE 9:
#    📊 Punti prima: 1853
#    ✅ Cluster 1: 135 punti
#    ✅ Cluster 2: 121 punti
#    ✅ Cluster 3: 119 punti
#    📊 Totale punti accettati: 375
#    📊 Location_ID unici accettati: 375
#    📊 Punti dopo rimozione: 1478
#    📊 Punti attesi dopo rimozione: 1478
#    📊 Rimossi effettivamente: 375
#    📊 Dovevano essere rimossi: 375
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 10: soglia = 1700 min
#    • Punti rimanenti: 1478
#       ✅ Cluster 1: 123 punti, max_mean=401.1min, overtime=0, motivo=mean_range
#       ❌ Cluster 10: 145 punti, max_mean=337.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 139 punti, max_mean=349.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 28 punti, max_mean=133.1min, overtime=0, RIFIUTATO
#       ✅ Cluster 2: 122 punti, max_mean=379.6min, overtime=2, motivo=overtime_ok
#       ✅ Cluster 3: 130 punti, max_mean=395.3min, overtime=0, motivo=mean_range
#       ✅ Cluster 4: 132 punti, max_mean=426.2min, overtime=2, motivo=mean_range
#       ❌ Cluster 5: 137 punti, max_mean=377.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 125 punti, max_mean=389.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 120 punti, max_mean=387.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 136 punti, max_mean=387.6min, overtime=0, RIFIUTATO
#       ✅ Cluster 9: 141 punti, max_mean=379.6min, overtime=1, motivo=overtime_ok
#    ✅ Cluster accettati: 5/12
#
# 🔍 DIAGNOSTICA ITERAZIONE 10:
#    📊 Punti prima: 1478
#    ✅ Cluster 1: 123 punti
#    ✅ Cluster 2: 122 punti
#    ✅ Cluster 3: 130 punti
#    ✅ Cluster 4: 132 punti
#    ✅ Cluster 5: 141 punti
#    📊 Totale punti accettati: 648
#    📊 Location_ID unici accettati: 648
#    📊 Punti dopo rimozione: 830
#    📊 Punti attesi dopo rimozione: 830
#    📊 Rimossi effettivamente: 648
#    📊 Dovevano essere rimossi: 648
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 11: soglia = 1800 min
#    • Punti rimanenti: 830
#       ✅ Cluster 1: 146 punti, max_mean=402.5min, overtime=0, motivo=mean_range
#       ✅ Cluster 2: 134 punti, max_mean=430.0min, overtime=3, motivo=mean_range
#       ✅ Cluster 3: 129 punti, max_mean=411.5min, overtime=0, motivo=mean_range
#       ✅ Cluster 4: 146 punti, max_mean=395.7min, overtime=0, motivo=mean_range
#       ❌ Cluster 5: 153 punti, max_mean=377.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 122 punti, max_mean=344.3min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 4/6
#
# 🔍 DIAGNOSTICA ITERAZIONE 11:
#    📊 Punti prima: 830
#    ✅ Cluster 1: 146 punti
#    ✅ Cluster 2: 134 punti
#    ✅ Cluster 3: 129 punti
#    ✅ Cluster 4: 146 punti
#    📊 Totale punti accettati: 555
#    📊 Location_ID unici accettati: 555
#    📊 Punti dopo rimozione: 275
#    📊 Punti attesi dopo rimozione: 275
#    📊 Rimossi effettivamente: 555
#    📊 Dovevano essere rimossi: 555
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 12: soglia = 1900 min
#    • Punti rimanenti: 275
#       ✅ Cluster 1: 162 punti, max_mean=405.4min, overtime=0, motivo=mean_range
#       ❌ Cluster 2: 113 punti, max_mean=312.0min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/2
#
# 🔍 DIAGNOSTICA ITERAZIONE 12:
#    📊 Punti prima: 275
#    ✅ Cluster 1: 162 punti
#    📊 Totale punti accettati: 162
#    📊 Location_ID unici accettati: 162
#    📊 Punti dopo rimozione: 113
#    📊 Punti attesi dopo rimozione: 113
#    📊 Rimossi effettivamente: 162
#    📊 Dovevano essere rimossi: 162
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 13: soglia = 2000 min
#    • Punti rimanenti: 113
#       ❌ Cluster 1: 113 punti, max_mean=312.0min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/1
#
# 🔍 DIAGNOSTICA ITERAZIONE 13:
#    📊 Punti prima: 113
#    📊 Totale punti accettati: 0
#    📊 Location_ID unici accettati: 0
#    📊 Punti dopo rimozione: 113
#    📊 Punti attesi dopo rimozione: 113
#    📊 Rimossi effettivamente: 0
#    📊 Dovevano essere rimossi: 0
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 14: soglia = 2100 min
#    • Punti rimanenti: 113
#       ❌ Cluster 1: 113 punti, max_mean=312.0min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/1
#
# 🔍 DIAGNOSTICA ITERAZIONE 14:
#    📊 Punti prima: 113
#    📊 Totale punti accettati: 0
#    📊 Location_ID unici accettati: 0
#    📊 Punti dopo rimozione: 113
#    📊 Punti attesi dopo rimozione: 113
#    📊 Rimossi effettivamente: 0
#    📊 Dovevano essere rimossi: 0
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 15: soglia = 2200 min
#    • Punti rimanenti: 113
#       ❌ Cluster 1: 113 punti, max_mean=312.0min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/1
#
# 🔍 DIAGNOSTICA ITERAZIONE 15:
#    📊 Punti prima: 113
#    📊 Totale punti accettati: 0
#    📊 Location_ID unici accettati: 0
#    📊 Punti dopo rimozione: 113
#    📊 Punti attesi dopo rimozione: 113
#    📊 Rimossi effettivamente: 0
#    📊 Dovevano essere rimossi: 0
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔧 Assemblaggio soluzione finale...
#    📋 Punti non assegnati: 113
#    🔍 Recuperando cluster rifiutati dall'ultima iterazione...
#    🔍 Recuperando cluster rifiutati dall'ultima iterazione (15)
#    📋 Cluster rifiutati disponibili: 1
#    ✅ Cluster recuperati dopo filtro: 1 (113 punti)
#
# 📊 Calcolando performance finali per 29 cluster...
#
# 🏁 COMPLETATO:
#    • Iterazioni eseguite: 15
#    • Cluster finali totali: 29
#    • Punti totali assegnati: 3219
#    • Copertura: 3219/3219 punti
#
# 📊 Cluster con più di 1 giorno overtime: 7
#
# 🔄 REFINEMENT NECESSARIO: 7 cluster con overtime > 1
#    🚀 Avvio 5 cicli aggiuntivi con soglia 1550 min (+60/iterazione)...
#    📋 Cluster problematici: 7
#    📋 Punti da riclusterare: 763
# 🔄 INIZIO clustering iterativo COMPLETO con soglia crescente
#    • Soglia iniziale: 1550 min
#    • Incremento: +60 min per iterazione
#
# 🔄 Iterazione 1: soglia = 1550 min
#    • Punti rimanenti: 763
#       ❌ Cluster 1: 109 punti, max_mean=378.9min, overtime=0, RIFIUTATO
#       ✅ Cluster 2: 108 punti, max_mean=444.3min, overtime=3, motivo=mean_range
#       ✅ Cluster 3: 112 punti, max_mean=443.3min, overtime=1, motivo=mean_range
#       ❌ Cluster 4: 119 punti, max_mean=370.6min, overtime=0, RIFIUTATO
#       ✅ Cluster 5: 112 punti, max_mean=441.1min, overtime=1, motivo=mean_range
#       ✅ Cluster 6: 116 punti, max_mean=411.2min, overtime=1, motivo=mean_range
#       ❌ Cluster 7: 87 punti, max_mean=338.3min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 4/7
#
# 🔄 Iterazione 2: soglia = 1610 min
#    • Punti rimanenti: 315
#       ❌ Cluster 1: 114 punti, max_mean=378.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 124 punti, max_mean=379.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 77 punti, max_mean=306.2min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/3
#
# 🔄 Iterazione 3: soglia = 1670 min
#    • Punti rimanenti: 315
#       ❌ Cluster 1: 118 punti, max_mean=378.9min, overtime=0, RIFIUTATO
#       ✅ Cluster 2: 129 punti, max_mean=413.9min, overtime=2, motivo=mean_range
#       ❌ Cluster 3: 68 punti, max_mean=274.2min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/3
#
# 🔄 Iterazione 4: soglia = 1730 min
#    • Punti rimanenti: 186
#       ❌ Cluster 1: 121 punti, max_mean=378.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 65 punti, max_mean=272.0min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/2
#
# 🔄 Iterazione 5: soglia = 1790 min
#    • Punti rimanenti: 186
#       ✅ Cluster 1: 127 punti, max_mean=419.9min, overtime=2, motivo=mean_range
#       ❌ Cluster 2: 59 punti, max_mean=250.6min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/2
#
# 🔧 Assemblaggio soluzione finale...
#    📋 Punti non assegnati: 59
#    🔍 Recuperando cluster rifiutati dall'ultima iterazione...
#    🔍 Recuperando cluster rifiutati dall'ultima iterazione (5)
#    📋 Cluster rifiutati disponibili: 1
#    ✅ Cluster recuperati dopo filtro: 1 (59 punti)
#
# 📊 Calcolando performance finali per 7 cluster...
#
# 🏁 COMPLETATO:
#    • Iterazioni eseguite: 5
#    • Cluster finali totali: 7
#    • Punti totali assegnati: 763
#    • Copertura: 763/763 punti
#
# 📊 Cluster con più di 1 giorno overtime: 3
#
# ✅ REFINEMENT COMPLETATO
#    • Nuovi cluster totali: 29
#    • Cluster con overtime > 1: 3 (prima: 7)
# Tempo di esecuzione algoritmo: 76.59 min
#
# 🎯 REFINEMENT APPLICATO con successo!

# %% [markdown]
# ### salvataggio risultati

# %%
final_performance.to_csv('clustering_methods_performances/euristic_complete_v2_ON_5.csv')

with open('cluster_dicts/cluster_dict_euristic_complete_v2_ON_5.pkl', 'wb') as f:
    pickle.dump(final_clusters, f)

# %% [markdown]
# # 3 full

# %%
def clustering_euristico_multicluster(full_time_mat_min: np.ndarray,
                                      index_to_location_id: list[int],
                                      delivery_points: pd.DataFrame,
                                      max_time: int = 500,
                                      unloading_time: int = 10):
    """
    Algoritmo Cluster‐First, Route‐Second:
    • seed = punto più distante dal deposito
    • greedy: aggiunge il punto che allunga meno il tour
    • stop quando supererebbe max_time
    """
    n_points = full_time_mat_min.shape[0]
    unassigned = set(range(1, n_points))          # deposito è indice 0
    clusters = []


    while unassigned:
        # --- nuovo cluster
        first_idx = max(unassigned, key=lambda i: full_time_mat_min[0, i])
        cluster = [first_idx]
        unassigned.remove(first_idx)
        cluster_time = full_time_mat_min[0, first_idx] * 2 + unloading_time


        # --- inserimento greedy
        while unassigned:
            # tempo minimo dal cluster al candidato
            cand, min_cost = min(
                ((c, min(full_time_mat_min[p, c] for p in cluster)) for c in unassigned),
                key=lambda x: x[1]
            )
            if cluster_time + min_cost + unloading_time > max_time:
                break
            cluster.append(cand)
            unassigned.remove(cand)
            cluster_time += min_cost + unloading_time


        clusters.append([index_to_location_id[i] for i in cluster])


    return clusters



def plot_clusters(clusters, delivery_points, title):
    """Visual plot rapido"""
    cmap = plt.cm.get_cmap("tab20", len(clusters))
    plt.figure(figsize=(10, 7))
    for i, cl in enumerate(clusters):
        sub = delivery_points[delivery_points["location_id"].isin(cl)]
        plt.scatter(sub["lon"], sub["lat"], c=[cmap(i)],
                    label=f"C{i+1}", alpha=.7, s=20, edgecolors="k")
    plt.title(title)
    plt.xlabel("lon"); plt.ylabel("lat")
    plt.legend(ncol=2, fontsize="small")
    plt.show()


def deduplicate_clusters(clusters, already_assigned_points):
    """
    Rimuove punti già assegnati dai cluster e restituisce solo cluster validi
    
    Args:
        clusters: lista di cluster (liste di location_id)
        already_assigned_points: set di location_id già assegnati
        
    Returns:
        result: lista di cluster puliti
        assigned: set aggiornato di punti assegnati
    """
    assigned = set(already_assigned_points)
    result = []
    
    for cluster in clusters:
        clean_cluster = [loc_id for loc_id in cluster if loc_id not in assigned]
        if clean_cluster:  # Solo se il cluster ha almeno un punto
            result.append(clean_cluster)
            assigned.update(clean_cluster)
    
    return result, assigned


def get_last_iteration_rejected_clusters(all_results, already_assigned_points, verbose=True):
    """
    Recupera i cluster RIFIUTATI dell'ULTIMA iterazione, filtrando i punti già assegnati
    
    Args:
        all_results: dizionario con i risultati di tutte le iterazioni
        already_assigned_points: set di location_id già assegnati
        verbose: stampa messaggi di debug
        
    Returns:
        lista di cluster filtrati
    """
    if not all_results:
        return []
    
    # Prendi l'ultima iterazione
    last_iteration = max(all_results.keys())
    last_results = all_results[last_iteration]
    
    # Recupera i cluster rifiutati
    rejected_cluster_indices = last_results['rejected_indices']
    all_clusters = last_results['clusters']
    rejected_clusters = [all_clusters[i] for i in rejected_cluster_indices]
    
    if verbose:
        print(f"   🔍 Recuperando cluster rifiutati dall'ultima iterazione ({last_iteration})")
        print(f"   📋 Cluster rifiutati disponibili: {len(rejected_clusters)}")
    
    # Filtra punti già assegnati
    filtered_clusters, _ = deduplicate_clusters(rejected_clusters, already_assigned_points)
    
    if verbose:
        total_points = sum(len(cl) for cl in filtered_clusters)
        print(f"   ✅ Cluster recuperati dopo filtro: {len(filtered_clusters)} ({total_points} punti)")
    
    return filtered_clusters


def count_clusters_with_excessive_overtime(performance_df, threshold=1):
    """
    Conta quanti cluster hanno più di 'threshold' giorni di overtime
    
    Args:
        performance_df: DataFrame con le performance dei cluster
        threshold: soglia di overtime (default 1)
        
    Returns:
        numero di cluster con overtime > threshold
    """
    count = 0
    for cluster_name, cluster_data in performance_df.groupby('cluster'):
        total_overtime = cluster_data['n_overtime_days'].sum()
        if total_overtime > threshold:
            count += 1
    return count



def evaluate_and_accept_clusters(clusters, performance_df, verbose=True):
    """
    Valuta i cluster e decide quali accettare basandosi sui criteri:
    1) Media giornaliera tra 390-480 minuti
    2) Overtime accettabile (massimo 1 giorno per tipo di giorno della settimana)
    
    Returns:
        accepted_clusters: list di cluster (liste di location_id) accettati
        rejected_indices: list di indici dei cluster rifiutati
    """
    accepted_clusters = []
    rejected_indices = []
    
    # Raggruppa performance per cluster
    for cluster_name, cluster_data in performance_df.groupby('cluster'):
        cluster_index = int(cluster_name.split()[-1]) - 1  # "Cluster 1" -> index 0
        cluster = clusters[cluster_index]
        
        # CRITERIO 1: Media giornaliera tra 390-480 minuti
        mean_minutes_range = cluster_data['mean_minutes'].between(390, 480).any()
        
        # CRITERIO 2: Overtime accettabile
        overtime_acceptable = check_overtime_acceptable(cluster_data)
        
        if mean_minutes_range or overtime_acceptable:
            accepted_clusters.append(cluster)
            if verbose:
                max_mean = cluster_data['mean_minutes'].max()
                total_overtime = cluster_data['n_overtime_days'].sum()
                reason = "mean_range" if mean_minutes_range else "overtime_ok"
                print(f"      ✅ {cluster_name}: {len(cluster)} punti, "
                      f"max_mean={max_mean:.1f}min, overtime={total_overtime}, "
                      f"motivo={reason}")
        else:
            rejected_indices.append(cluster_index)
            if verbose:
                max_mean = cluster_data['mean_minutes'].max()
                total_overtime = cluster_data['n_overtime_days'].sum()
                print(f"      ❌ {cluster_name}: {len(cluster)} punti, "
                      f"max_mean={max_mean:.1f}min, overtime={total_overtime}, "
                      f"RIFIUTATO")
    
    return accepted_clusters, rejected_indices



def check_overtime_acceptable(cluster_data):
    """
    Controlla se l'overtime è accettabile:
    massimo 1 giorno di overtime per ogni giorno della settimana
    
    Args:
        cluster_data: DataFrame con performance di un singolo cluster
    
    Returns:
        bool: True se overtime accettabile, False altrimenti
    """
    # Controlla per ogni giorno della settimana
    for _, row in cluster_data.iterrows():
        if row['n_overtime_days'] > 1:  # Più di 1 giorno di overtime per questo weekday -> non accettato
            return False
        elif row['n_overtime_days'] == 1:
            return True  # Ok, 1 giorno di overtime è accettabile
    
    return False






def assemble_final_performance_from_cache(all_results, final_complete_clusters, verbose=True):
    """
    Assembla un DataFrame finale dalle performance già calcolate nelle iterazioni.
    Molto più veloce del ricalcolo completo.
    """
    if verbose:
        print("📋 Assemblando performance finali da cache esistenti...")
    
    final_performance_pieces = []
    cluster_counter = 1
    
    for cluster in final_complete_clusters:
        cluster_found = False
        
        # Cerca questo cluster nelle iterazioni passate
        for iteration_num, results in all_results.items():
            for i, iter_cluster in enumerate(results['clusters']):
                if set(iter_cluster) == set(cluster):  # Stesso cluster
                    # Prendi le performance già calcolate
                    iter_perf_df = results['performance_df']
                    cluster_name_old = f"Cluster {i+1}"
                    cluster_data = iter_perf_df[iter_perf_df['cluster'] == cluster_name_old].copy()
                    
                    # Rinomina con il nuovo indice
                    cluster_data['cluster'] = f"Cluster {cluster_counter}"
                    final_performance_pieces.append(cluster_data)
                    cluster_counter += 1
                    cluster_found = True
                    break
            
            if cluster_found:
                break
        
        if not cluster_found and verbose:
            print(f"   ⚠️ Cluster non trovato in cache - dovrà essere ricalcolato")
    
    if final_performance_pieces:
        final_df = pd.concat(final_performance_pieces, ignore_index=True)
        if verbose:
            print(f"   ✅ Assemblate performance per {len(final_performance_pieces)} cluster da cache")
        return final_df
    else:
        if verbose:
            print("   ⚠️ Nessuna performance in cache - calcolo completo necessario")
        return None



def heuristic_iterative_clustering_complete(delivery_points: pd.DataFrame,
                                           depot_location: tuple[float, float],
                                           initial_threshold: int = 800,
                                           increment_threshold: int = 120,
                                           unload_min: int = 10,
                                           max_iterations: int = 10,
                                           verbose: bool = True,
                                           enable_diagnostics: bool = False):
    """
    Algoritmo iterativo che restituisce TUTTI i punti assegnati a cluster.
    MODIFICHE:
    - Ogni punto assegnato ad un solo cluster (no duplicati)
    - Fallback all'ultima iterazione per punti non assegnati
    - Refinement automatico se >5 cluster con overtime >1
    
    Returns:
        all_results: dict con tutti i risultati intermedi
        final_complete_clusters: list di TUTTI i cluster (accettati + migliori fallback)
        final_performance: DataFrame con performance di tutti i cluster finali
        refinement_applied: bool indicante se è stato applicato refinement
    """
    
    if verbose:
        print("🔄 INIZIO clustering iterativo COMPLETO con soglia crescente")
        print(f"   • Soglia iniziale: {initial_threshold} min")
        print(f"   • Incremento: +{increment_threshold} min per iterazione")
    
    all_results = {}
    remaining_points = delivery_points.copy()
    original_points = set(delivery_points['location_id'])
    already_assigned_points = set()  # NUOVO: Traccia globale dei punti già assegnati
    current_threshold = initial_threshold
    
    for iteration in range(max_iterations):
        if verbose:
            print(f"\n🔄 Iterazione {iteration + 1}: soglia = {current_threshold} min")
            print(f"   • Punti rimanenti: {len(remaining_points)}")
        
        if remaining_points.empty:
            if verbose:
                print("   ✅ Nessun punto rimanente - STOP")
            break
        
        # ================== CLUSTERING ==================
        dm, tm, idx2loc, _ = pc.distance_matrix_creation('', remaining_points)
        clusters = clustering_euristico_multicluster(
            tm, idx2loc, remaining_points,
            max_time=current_threshold,
            unloading_time=unload_min
        )
        
        if not clusters:
            if verbose:
                print("   ⚠️ Nessun cluster generato - STOP")
            break
        
        # ================== PERFORMANCE ==================
        performance_df = pc.calc_clusters_stats(
            clusters, time_limit=3, parallel=True, max_workers=7, verbose=False
        )
        
        # ================== VALUTAZIONE E ACCETTAZIONE ==================
        accepted_clusters, rejected_cluster_indices = evaluate_and_accept_clusters(
            clusters, performance_df, verbose=verbose
        )
        
        # Salva risultati dell'iterazione (con rejected_indices invece di rejected_clusters)
        all_results[iteration + 1] = {
            'threshold': current_threshold,
            'clusters': clusters,
            'performance_df': performance_df,
            'accepted_clusters': accepted_clusters,
            'rejected_indices': rejected_cluster_indices
        }
        
        if verbose:
            print(f"   ✅ Cluster accettati: {len(accepted_clusters)}/{len(clusters)}")
        
        # ================== RIMOZIONE PUNTI ACCETTATI (NO DUPLICATI) ==================
        accepted_location_ids = set()
        for cluster in accepted_clusters:
            accepted_location_ids.update(cluster)
        
        # NUOVO: Filtra solo gli ID che esistono effettivamente nel DataFrame
        existing_ids = set(remaining_points['location_id'])
        valid_accepted_ids = accepted_location_ids.intersection(existing_ids)
        missing_ids = accepted_location_ids - existing_ids
        
        if verbose and missing_ids:
            print(f'   ⚠️ ID nei cluster ma non nel DataFrame: {len(missing_ids)} ID')
            print(f'   🔧 ID validi da rimuovere: {len(valid_accepted_ids)} ID')
        
        # NUOVO: Aggiorna il set globale dei punti assegnati
        already_assigned_points.update(valid_accepted_ids)

        # PER LA DIAGNOSTICA (opzionale):
        if enable_diagnostics and verbose:
            remaining_points_after_removal = remaining_points[
                ~remaining_points["location_id"].isin(valid_accepted_ids)
            ].copy()
            diagnose_point_removal(remaining_points, accepted_clusters, 
                remaining_points_after_removal, iteration + 1)
        
        # USA VALID_ACCEPTED_IDS invece di ACCEPTED_LOCATION_IDS
        remaining_points = remaining_points[
            ~remaining_points['location_id'].isin(valid_accepted_ids)
        ].copy()
        
        # Se tutti i cluster sono stati accettati, abbiamo finito
        if len(accepted_clusters) == len(clusters):
            if verbose:
                print("   🎯 Tutti i cluster sono stati accettati - STOP")
            break
        
        # Incrementa soglia per prossima iterazione
        current_threshold += increment_threshold
    
    # ================== ASSEMBLAGGIO FINALE ==================
    if verbose:
        print(f"\n🔧 Assemblaggio soluzione finale...")
    
    final_complete_clusters = []
    
    # 1. Aggiungi tutti i cluster accettati (già senza duplicati)
    for iteration_results in all_results.values():
        for cluster in iteration_results['accepted_clusters']:
            final_complete_clusters.append(cluster)
    
    # 2. NUOVO: Per i punti rimanenti, usa i cluster RIFIUTATI dell'ULTIMA ITERAZIONE
    unassigned_points = original_points - already_assigned_points
    
    if unassigned_points:
        if verbose:
            print(f"   📋 Punti non assegnati: {len(unassigned_points)}")
            print("   🔍 Recuperando cluster rifiutati dall'ultima iterazione...")
        
        last_iteration_clusters = get_last_iteration_rejected_clusters(
            all_results, already_assigned_points, verbose
        )
        
        final_complete_clusters.extend(last_iteration_clusters)
        for cluster in last_iteration_clusters:
            already_assigned_points.update(cluster)
    
    # ================== PERFORMANCE FINALI ==================
    if verbose:
        print(f"\n📊 Calcolando performance finali per {len(final_complete_clusters)} cluster...")
    
    # Calcola performance (senza cache per ora, per evitare problemi)
    final_performance = pc.calc_clusters_stats(
        final_complete_clusters, time_limit=3, parallel=True, max_workers=7, verbose=False
    )
    
    if verbose:
        total_points = sum(len(cluster) for cluster in final_complete_clusters)
        print(f"\n🏁 COMPLETATO:")
        print(f"   • Iterazioni eseguite: {len(all_results)}")
        print(f"   • Cluster finali totali: {len(final_complete_clusters)}")
        print(f"   • Punti totali assegnati: {total_points}")
        print(f"   • Copertura: {total_points}/{len(original_points)} punti")
        
        missing = len(original_points) - total_points
        if missing > 0:
            print(f"   ⚠️ Punti mancanti: {missing}")
    
    # ================== CHECK OVERTIME ECCESSIVO E REFINEMENT ==================
    excessive_overtime_count = count_clusters_with_excessive_overtime(final_performance, threshold=1)
    
    if verbose:
        print(f"\n📊 Cluster con più di 1 giorno overtime: {excessive_overtime_count}")
    
    # NUOVO: Se ci sono più di 5 cluster con overtime eccessivo, applica refinement
    refinement_needed = excessive_overtime_count > 5
    
    if refinement_needed:
        if verbose:
            print(f"\n🔄 REFINEMENT NECESSARIO: {excessive_overtime_count} cluster con overtime > 1")
            print("   🚀 Avvio 5 cicli aggiuntivi con soglia 1550 min (+60/iterazione)...")
        
        # Identifica i punti nei cluster problematici
        problematic_points = set()
        problematic_cluster_names = []
        for cluster_name, cluster_data in final_performance.groupby('cluster'):
            total_overtime = cluster_data['n_overtime_days'].sum()
            if total_overtime > 1:
                problematic_cluster_names.append(cluster_name)
                cluster_index = int(cluster_name.split()[-1]) - 1
                problematic_cluster = final_complete_clusters[cluster_index]
                problematic_points.update(problematic_cluster)
        
        # Crea DataFrame con i punti problematici
        refinement_points = delivery_points[
            delivery_points['location_id'].isin(problematic_points)
        ].copy()
        
        if verbose:
            print(f"   📋 Cluster problematici: {len(problematic_cluster_names)}")
            print(f"   📋 Punti da riclusterare: {len(refinement_points)}")
        
        # Applica refinement (ricorsivo)
        refinement_results, refinement_clusters, refinement_performance, _ = heuristic_iterative_clustering_complete(
            delivery_points=refinement_points,
            depot_location=depot_location,
            initial_threshold=1550,  # NUOVO: soglia più alta
            increment_threshold=60,   # NUOVO: incremento più piccolo
            unload_min=unload_min,
            max_iterations=5,        # NUOVO: max 5 iterazioni
            verbose=verbose,
            enable_diagnostics=False  # Disabilita diagnostica nel refinement
        )
        
        # Sostituisci i cluster problematici con quelli raffinati
        final_complete_clusters = [
            cl for cl in final_complete_clusters 
            if not any(p in problematic_points for p in cl)
        ]
        final_complete_clusters.extend(refinement_clusters)
        
        # Ricalcola performance finali
        final_performance = pc.calc_clusters_stats(
            final_complete_clusters, time_limit=3, parallel=True, max_workers=7, verbose=False
        )
        
        if verbose:
            print(f"\n✅ REFINEMENT COMPLETATO")
            print(f"   • Nuovi cluster totali: {len(final_complete_clusters)}")
            excessive_after = count_clusters_with_excessive_overtime(final_performance, threshold=1)
            print(f"   • Cluster con overtime > 1: {excessive_after} (prima: {excessive_overtime_count})")
        
        return all_results, final_complete_clusters, final_performance, True
    
    return all_results, final_complete_clusters, final_performance, False





def plot_iteration_results(all_results, delivery_points, iteration_to_plot=None):
    """
    Plotta i risultati di una specifica iterazione o dell'ultima
    """
    if iteration_to_plot is None:
        iteration_to_plot = max(all_results.keys())
    
    if iteration_to_plot not in all_results:
        print(f"Iterazione {iteration_to_plot} non trovata")
        return
    
    results = all_results[iteration_to_plot]
    clusters = results['clusters']
    threshold = results['threshold']
    accepted = results['accepted_clusters']
    
    plot_clusters(clusters, delivery_points, 
                  f"Iterazione {iteration_to_plot} - Soglia {threshold} min "
                  f"({len(accepted)} accettati/{len(clusters)} totali)")



# ------------------------------------------------
# ----------------------------------------------------------------------------------------
# SOLO PER DEBUG
# ----------------------------------------------------------------------------------------
# ------------------------------------------------


def diagnose_point_removal(remaining_points_before, accepted_clusters, remaining_points_after, iteration):
    """Diagnostica dettagliata per capire la discrepanza"""
    
    print(f"\n🔍 DIAGNOSTICA ITERAZIONE {iteration}:")
    
    # 1. Conta punti prima
    points_before = len(remaining_points_before)
    print(f"   📊 Punti prima: {points_before}")
    
    # 2. Conta punti negli cluster accettati
    accepted_location_ids = set()
    total_accepted_points = 0
    for i, cluster in enumerate(accepted_clusters):
        cluster_size = len(cluster)
        total_accepted_points += cluster_size
        accepted_location_ids.update(cluster)
        print(f"   ✅ Cluster {i+1}: {cluster_size} punti")
    
    print(f"   📊 Totale punti accettati: {total_accepted_points}")
    print(f"   📊 Location_ID unici accettati: {len(accepted_location_ids)}")
    
    # 3. Verifica che tutti i location_id accettati esistano in remaining_points_before
    existing_ids = set(remaining_points_before['location_id'])
    missing_ids = accepted_location_ids - existing_ids
    if missing_ids:
        print(f"   ⚠️ PROBLEMA: {len(missing_ids)} ID accettati non esistono in remaining_points!")
        print(f"      ID mancanti: {list(missing_ids)[:10]}...")
    
    # 4. Simula la rimozione manualmente
    should_remain = remaining_points_before[
        ~remaining_points_before['location_id'].isin(accepted_location_ids)
    ]
    expected_remaining = len(should_remain)
    
    # 5. Conta punti dopo
    points_after = len(remaining_points_after)
    print(f"   📊 Punti dopo rimozione: {points_after}")
    print(f"   📊 Punti attesi dopo rimozione: {expected_remaining}")
    
    # 6. Calcola discrepanze
    actual_removed = points_before - points_after
    expected_removed = len(accepted_location_ids)
    discrepancy = total_accepted_points - actual_removed
    
    print(f"   📊 Rimossi effettivamente: {actual_removed}")
    print(f"   📊 Dovevano essere rimossi: {expected_removed}")
    print(f"   📊 DISCREPANZA: {discrepancy}")
    
    if discrepancy != 0:
        print(f"   ❌ DISCREPANZA RILEVATA!")
        
        # Analisi più profonda
        if points_after != expected_remaining:
            print(f"   🔍 Il DataFrame finale non corrisponde alla simulazione")
            print(f"   🔍 Differenza: {points_after - expected_remaining}")
    
    print(f"   ✅ Diagnostica completata\n")
    
    return {
        'points_before': points_before,
        'total_accepted_points': total_accepted_points,
        'actual_removed': actual_removed,
        'discrepancy': discrepancy
    }

# ------------------------------------------------
# ----------------------------------------------------------------------------------------
# FINE DEBUG
# ----------------------------------------------------------------------------------------
# ------------------------------------------------

# %%
import time
start = time.time()

all_results, final_clusters, final_performance, refinement_applied = heuristic_iterative_clustering_complete(
    delivery_points=pc.delivery_points,
    depot_location=pc.depot_location,
    initial_threshold=800,
    increment_threshold=100,
    unload_min=10,
    max_iterations=15,
    verbose=True,
    enable_diagnostics=True  # Metti False per disabilitare la diagnostica
)


end = time.time()
print(f"Tempo di esecuzione algoritmo: {(end - start)/60:.2f} min")

# Stampa risultato refinement
if refinement_applied:
    print("\n🎯 REFINEMENT APPLICATO con successo!")
else:
    print("\n✅ NESSUN REFINEMENT necessario - soluzione ottimale trovata")
# Out:
# 🔄 INIZIO clustering iterativo COMPLETO con soglia crescente
#    • Soglia iniziale: 800 min
#    • Incremento: +100 min per iterazione
#
# 🔄 Iterazione 1: soglia = 800 min
#    • Punti rimanenti: 3764
#       ✅ Cluster 1: 42 punti, max_mean=413.9min, overtime=2, motivo=mean_range
#       ❌ Cluster 10: 51 punti, max_mean=218.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 53 punti, max_mean=250.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 52 punti, max_mean=201.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 50 punti, max_mean=296.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 55 punti, max_mean=236.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 55 punti, max_mean=205.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 50 punti, max_mean=216.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 50 punti, max_mean=228.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 56 punti, max_mean=219.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 56 punti, max_mean=210.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 41 punti, max_mean=246.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 56 punti, max_mean=179.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 54 punti, max_mean=226.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 62 punti, max_mean=259.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 55 punti, max_mean=248.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 61 punti, max_mean=351.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 58 punti, max_mean=188.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 56 punti, max_mean=293.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 58 punti, max_mean=197.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 54 punti, max_mean=212.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 58 punti, max_mean=306.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 45 punti, max_mean=254.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 61 punti, max_mean=214.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 58 punti, max_mean=311.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 57 punti, max_mean=238.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 60 punti, max_mean=195.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 59 punti, max_mean=218.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 61 punti, max_mean=258.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 62 punti, max_mean=202.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 61 punti, max_mean=219.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 59 punti, max_mean=205.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 63 punti, max_mean=199.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 47 punti, max_mean=338.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 40: 63 punti, max_mean=182.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 41: 61 punti, max_mean=215.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 42: 57 punti, max_mean=228.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 43: 63 punti, max_mean=220.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 44: 65 punti, max_mean=178.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 45: 63 punti, max_mean=202.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 46: 61 punti, max_mean=191.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 47: 63 punti, max_mean=138.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 48: 66 punti, max_mean=192.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 49: 68 punti, max_mean=188.3min, overtime=0, RIFIUTATO
#       ✅ Cluster 5: 49 punti, max_mean=419.8min, overtime=2, motivo=mean_range
#       ❌ Cluster 50: 67 punti, max_mean=151.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 51: 67 punti, max_mean=214.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 52: 62 punti, max_mean=162.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 53: 67 punti, max_mean=198.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 54: 62 punti, max_mean=180.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 55: 67 punti, max_mean=142.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 56: 67 punti, max_mean=183.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 57: 67 punti, max_mean=227.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 58: 65 punti, max_mean=161.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 59: 67 punti, max_mean=180.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 49 punti, max_mean=253.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 60: 67 punti, max_mean=159.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 61: 68 punti, max_mean=144.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 62: 68 punti, max_mean=127.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 63: 66 punti, max_mean=129.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 64: 64 punti, max_mean=113.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 65: 17 punti, max_mean=57.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 51 punti, max_mean=223.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 49 punti, max_mean=225.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 52 punti, max_mean=242.0min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 2/65
#
# 🔍 DIAGNOSTICA ITERAZIONE 1:
#    📊 Punti prima: 3764
#    ✅ Cluster 1: 42 punti
#    ✅ Cluster 2: 49 punti
#    📊 Totale punti accettati: 91
#    📊 Location_ID unici accettati: 91
#    📊 Punti dopo rimozione: 3673
#    📊 Punti attesi dopo rimozione: 3673
#    📊 Rimossi effettivamente: 91
#    📊 Dovevano essere rimossi: 91
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 2: soglia = 900 min
#    • Punti rimanenti: 3673
#       ❌ Cluster 1: 48 punti, max_mean=270.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 60 punti, max_mean=217.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 59 punti, max_mean=299.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 62 punti, max_mean=236.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 65 punti, max_mean=216.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 59 punti, max_mean=232.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 59 punti, max_mean=235.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 64 punti, max_mean=261.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 64 punti, max_mean=217.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 59 punti, max_mean=267.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 64 punti, max_mean=258.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 54 punti, max_mean=310.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 68 punti, max_mean=303.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 66 punti, max_mean=222.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 62 punti, max_mean=307.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 69 punti, max_mean=188.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 65 punti, max_mean=195.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 70 punti, max_mean=326.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 66 punti, max_mean=312.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 67 punti, max_mean=278.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 68 punti, max_mean=265.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 66 punti, max_mean=273.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 55 punti, max_mean=363.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 70 punti, max_mean=250.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 71 punti, max_mean=258.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 65 punti, max_mean=189.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 72 punti, max_mean=203.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 68 punti, max_mean=222.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 71 punti, max_mean=260.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 64 punti, max_mean=217.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 72 punti, max_mean=194.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 71 punti, max_mean=255.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 74 punti, max_mean=225.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 56 punti, max_mean=283.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 40: 76 punti, max_mean=186.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 41: 76 punti, max_mean=224.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 42: 74 punti, max_mean=197.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 43: 74 punti, max_mean=198.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 44: 76 punti, max_mean=244.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 45: 74 punti, max_mean=184.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 46: 76 punti, max_mean=160.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 47: 77 punti, max_mean=172.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 48: 77 punti, max_mean=159.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 49: 76 punti, max_mean=201.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 60 punti, max_mean=251.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 50: 76 punti, max_mean=110.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 51: 77 punti, max_mean=131.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 52: 71 punti, max_mean=207.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 53: 74 punti, max_mean=138.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 54: 72 punti, max_mean=114.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 55: 53 punti, max_mean=105.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 58 punti, max_mean=235.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 61 punti, max_mean=282.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 60 punti, max_mean=261.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 62 punti, max_mean=271.4min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 0/55
#
# 🔍 DIAGNOSTICA ITERAZIONE 2:
#    📊 Punti prima: 3673
#    📊 Totale punti accettati: 0
#    📊 Location_ID unici accettati: 0
#    📊 Punti dopo rimozione: 3673
#    📊 Punti attesi dopo rimozione: 3673
#    📊 Rimossi effettivamente: 0
#    📊 Dovevano essere rimossi: 0
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 3: soglia = 1000 min
#    • Punti rimanenti: 3673
#       ❌ Cluster 1: 57 punti, max_mean=310.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 67 punti, max_mean=251.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 67 punti, max_mean=299.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 70 punti, max_mean=245.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 71 punti, max_mean=244.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 68 punti, max_mean=254.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 68 punti, max_mean=266.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 71 punti, max_mean=242.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 68 punti, max_mean=280.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 72 punti, max_mean=329.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 76 punti, max_mean=251.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 62 punti, max_mean=318.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 76 punti, max_mean=239.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 71 punti, max_mean=313.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 76 punti, max_mean=205.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 71 punti, max_mean=184.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 76 punti, max_mean=314.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 77 punti, max_mean=231.8min, overtime=0, RIFIUTATO
#       ✅ Cluster 26: 75 punti, max_mean=348.3min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 27: 78 punti, max_mean=200.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 75 punti, max_mean=271.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 80 punti, max_mean=246.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 64 punti, max_mean=366.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 81 punti, max_mean=244.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 79 punti, max_mean=282.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 74 punti, max_mean=242.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 81 punti, max_mean=200.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 83 punti, max_mean=205.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 82 punti, max_mean=295.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 82 punti, max_mean=248.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 82 punti, max_mean=250.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 78 punti, max_mean=191.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 86 punti, max_mean=216.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 64 punti, max_mean=295.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 40: 82 punti, max_mean=172.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 41: 85 punti, max_mean=213.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 42: 85 punti, max_mean=170.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 43: 85 punti, max_mean=221.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 44: 85 punti, max_mean=175.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 45: 86 punti, max_mean=178.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 46: 83 punti, max_mean=189.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 47: 83 punti, max_mean=132.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 48: 80 punti, max_mean=153.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 49: 68 punti, max_mean=217.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 68 punti, max_mean=264.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 66 punti, max_mean=251.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 70 punti, max_mean=309.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 68 punti, max_mean=275.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 71 punti, max_mean=331.6min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/49
#
# 🔍 DIAGNOSTICA ITERAZIONE 3:
#    📊 Punti prima: 3673
#    ✅ Cluster 1: 75 punti
#    📊 Totale punti accettati: 75
#    📊 Location_ID unici accettati: 75
#    📊 Punti dopo rimozione: 3598
#    📊 Punti attesi dopo rimozione: 3598
#    📊 Rimossi effettivamente: 75
#    📊 Dovevano essere rimossi: 75
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 4: soglia = 1100 min
#    • Punti rimanenti: 3598
#       ❌ Cluster 1: 66 punti, max_mean=322.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 75 punti, max_mean=255.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 74 punti, max_mean=301.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 78 punti, max_mean=290.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 81 punti, max_mean=302.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 77 punti, max_mean=260.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 77 punti, max_mean=288.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 78 punti, max_mean=249.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 77 punti, max_mean=295.5min, overtime=0, RIFIUTATO
#       ✅ Cluster 18: 82 punti, max_mean=392.7min, overtime=0, motivo=mean_range
#       ❌ Cluster 19: 83 punti, max_mean=248.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 72 punti, max_mean=322.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 84 punti, max_mean=263.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 78 punti, max_mean=321.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 84 punti, max_mean=259.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 77 punti, max_mean=254.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 83 punti, max_mean=236.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 86 punti, max_mean=335.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 89 punti, max_mean=259.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 87 punti, max_mean=212.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 86 punti, max_mean=300.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 90 punti, max_mean=209.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 73 punti, max_mean=367.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 91 punti, max_mean=247.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 91 punti, max_mean=249.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 91 punti, max_mean=315.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 91 punti, max_mean=196.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 94 punti, max_mean=239.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 95 punti, max_mean=223.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 91 punti, max_mean=246.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 91 punti, max_mean=207.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 87 punti, max_mean=210.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 94 punti, max_mean=210.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 72 punti, max_mean=309.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 40: 91 punti, max_mean=149.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 41: 95 punti, max_mean=197.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 42: 93 punti, max_mean=141.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 43: 86 punti, max_mean=181.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 44: 22 punti, max_mean=87.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 77 punti, max_mean=266.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 74 punti, max_mean=256.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 78 punti, max_mean=305.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 77 punti, max_mean=292.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 80 punti, max_mean=358.8min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/44
#
# 🔍 DIAGNOSTICA ITERAZIONE 4:
#    📊 Punti prima: 3598
#    ✅ Cluster 1: 82 punti
#    📊 Totale punti accettati: 82
#    📊 Location_ID unici accettati: 82
#    📊 Punti dopo rimozione: 3516
#    📊 Punti attesi dopo rimozione: 3516
#    📊 Rimossi effettivamente: 82
#    📊 Dovevano essere rimossi: 82
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 5: soglia = 1200 min
#    • Punti rimanenti: 3516
#       ❌ Cluster 1: 74 punti, max_mean=358.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 84 punti, max_mean=275.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 81 punti, max_mean=230.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 86 punti, max_mean=331.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 90 punti, max_mean=282.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 86 punti, max_mean=264.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 86 punti, max_mean=314.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 87 punti, max_mean=292.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 94 punti, max_mean=275.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 85 punti, max_mean=341.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 91 punti, max_mean=238.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 81 punti, max_mean=324.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 85 punti, max_mean=319.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 95 punti, max_mean=250.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 87 punti, max_mean=236.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 94 punti, max_mean=321.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 96 punti, max_mean=262.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 95 punti, max_mean=276.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 98 punti, max_mean=248.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 96 punti, max_mean=229.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 99 punti, max_mean=225.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 99 punti, max_mean=277.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 82 punti, max_mean=378.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 98 punti, max_mean=304.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 103 punti, max_mean=280.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 104 punti, max_mean=226.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 101 punti, max_mean=223.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 98 punti, max_mean=286.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 103 punti, max_mean=207.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 36: 100 punti, max_mean=232.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 37: 102 punti, max_mean=155.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 38: 100 punti, max_mean=210.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 39: 50 punti, max_mean=98.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 80 punti, max_mean=317.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 86 punti, max_mean=268.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 82 punti, max_mean=262.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 85 punti, max_mean=325.5min, overtime=0, RIFIUTATO
#       ✅ Cluster 8: 84 punti, max_mean=350.4min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 9: 89 punti, max_mean=381.2min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/39
#
# 🔍 DIAGNOSTICA ITERAZIONE 5:
#    📊 Punti prima: 3516
#    ✅ Cluster 1: 84 punti
#    📊 Totale punti accettati: 84
#    📊 Location_ID unici accettati: 84
#    📊 Punti dopo rimozione: 3432
#    📊 Punti attesi dopo rimozione: 3432
#    📊 Rimossi effettivamente: 84
#    📊 Dovevano essere rimossi: 84
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 6: soglia = 1300 min
#    • Punti rimanenti: 3432
#       ✅ Cluster 1: 83 punti, max_mean=369.6min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 10: 89 punti, max_mean=271.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 95 punti, max_mean=342.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 100 punti, max_mean=305.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 95 punti, max_mean=291.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 95 punti, max_mean=341.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 97 punti, max_mean=326.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 101 punti, max_mean=266.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 91 punti, max_mean=354.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 104 punti, max_mean=284.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 94 punti, max_mean=331.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 90 punti, max_mean=326.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 105 punti, max_mean=245.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 96 punti, max_mean=256.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 107 punti, max_mean=280.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 105 punti, max_mean=274.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 100 punti, max_mean=303.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 105 punti, max_mean=309.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 108 punti, max_mean=254.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 109 punti, max_mean=300.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 111 punti, max_mean=258.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 109 punti, max_mean=227.7min, overtime=0, RIFIUTATO
#       ✅ Cluster 3: 90 punti, max_mean=391.9min, overtime=1, motivo=mean_range
#       ❌ Cluster 30: 112 punti, max_mean=232.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 31: 112 punti, max_mean=199.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 32: 113 punti, max_mean=187.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 33: 112 punti, max_mean=194.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 34: 106 punti, max_mean=238.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 35: 46 punti, max_mean=120.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 87 punti, max_mean=322.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 94 punti, max_mean=285.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 91 punti, max_mean=300.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 91 punti, max_mean=288.0min, overtime=0, RIFIUTATO
#       ✅ Cluster 8: 97 punti, max_mean=410.7min, overtime=1, motivo=mean_range
#       ❌ Cluster 9: 92 punti, max_mean=286.9min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 3/35
#
# 🔍 DIAGNOSTICA ITERAZIONE 6:
#    📊 Punti prima: 3432
#    ✅ Cluster 1: 83 punti
#    ✅ Cluster 2: 90 punti
#    ✅ Cluster 3: 97 punti
#    📊 Totale punti accettati: 270
#    📊 Location_ID unici accettati: 270
#    📊 Punti dopo rimozione: 3162
#    📊 Punti attesi dopo rimozione: 3162
#    📊 Rimossi effettivamente: 270
#    📊 Dovevano essere rimossi: 270
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 7: soglia = 1400 min
#    • Punti rimanenti: 3162
#       ❌ Cluster 1: 98 punti, max_mean=327.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 103 punti, max_mean=309.3min, overtime=0, RIFIUTATO
#       ✅ Cluster 11: 103 punti, max_mean=351.3min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 12: 106 punti, max_mean=359.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 110 punti, max_mean=279.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 98 punti, max_mean=364.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 113 punti, max_mean=302.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 100 punti, max_mean=335.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 113 punti, max_mean=294.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 107 punti, max_mean=304.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 117 punti, max_mean=272.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 96 punti, max_mean=328.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 114 punti, max_mean=273.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 113 punti, max_mean=270.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 121 punti, max_mean=300.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 122 punti, max_mean=285.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 121 punti, max_mean=241.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 114 punti, max_mean=299.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 121 punti, max_mean=275.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 118 punti, max_mean=257.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 28: 118 punti, max_mean=216.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 29: 112 punti, max_mean=212.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 103 punti, max_mean=298.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 30: 13 punti, max_mean=59.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 100 punti, max_mean=335.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 99 punti, max_mean=345.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 101 punti, max_mean=308.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 98 punti, max_mean=325.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 103 punti, max_mean=351.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 107 punti, max_mean=271.1min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 1/30
#
# 🔍 DIAGNOSTICA ITERAZIONE 7:
#    📊 Punti prima: 3162
#    ✅ Cluster 1: 103 punti
#    📊 Totale punti accettati: 103
#    📊 Location_ID unici accettati: 103
#    📊 Punti dopo rimozione: 3059
#    📊 Punti attesi dopo rimozione: 3059
#    📊 Rimossi effettivamente: 103
#    📊 Dovevano essere rimossi: 103
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 8: soglia = 1500 min
#    • Punti rimanenti: 3059
#       ❌ Cluster 1: 107 punti, max_mean=338.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 112 punti, max_mean=320.6min, overtime=0, RIFIUTATO
#       ✅ Cluster 11: 115 punti, max_mean=390.3min, overtime=1, motivo=mean_range
#       ❌ Cluster 12: 118 punti, max_mean=283.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 105 punti, max_mean=333.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 122 punti, max_mean=321.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 107 punti, max_mean=337.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 16: 122 punti, max_mean=305.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 17: 118 punti, max_mean=379.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 18: 126 punti, max_mean=296.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 122 punti, max_mean=320.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 104 punti, max_mean=337.6min, overtime=0, RIFIUTATO
#       ✅ Cluster 20: 122 punti, max_mean=354.3min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 21: 130 punti, max_mean=303.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 129 punti, max_mean=309.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 130 punti, max_mean=284.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 24: 126 punti, max_mean=266.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 25: 128 punti, max_mean=222.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 26: 121 punti, max_mean=155.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 27: 23 punti, max_mean=132.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 111 punti, max_mean=298.7min, overtime=0, RIFIUTATO
#       ❌ Cluster 4: 109 punti, max_mean=371.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 5: 108 punti, max_mean=296.0min, overtime=0, RIFIUTATO
#       ❌ Cluster 6: 109 punti, max_mean=314.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 7: 106 punti, max_mean=338.8min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 112 punti, max_mean=358.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 117 punti, max_mean=333.8min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 2/27
#
# 🔍 DIAGNOSTICA ITERAZIONE 8:
#    📊 Punti prima: 3059
#    ✅ Cluster 1: 115 punti
#    ✅ Cluster 2: 122 punti
#    📊 Totale punti accettati: 237
#    📊 Location_ID unici accettati: 237
#    📊 Punti dopo rimozione: 2822
#    📊 Punti attesi dopo rimozione: 2822
#    📊 Rimossi effettivamente: 237
#    📊 Dovevano essere rimossi: 237
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 9: soglia = 1600 min
#    • Punti rimanenti: 2822
#       ❌ Cluster 1: 115 punti, max_mean=345.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 10: 121 punti, max_mean=346.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 11: 113 punti, max_mean=348.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 12: 127 punti, max_mean=294.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 13: 113 punti, max_mean=344.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 14: 130 punti, max_mean=330.9min, overtime=0, RIFIUTATO
#       ❌ Cluster 15: 134 punti, max_mean=300.6min, overtime=0, RIFIUTATO
#       ✅ Cluster 16: 134 punti, max_mean=453.4min, overtime=14, motivo=mean_range
#       ✅ Cluster 17: 137 punti, max_mean=319.2min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 18: 135 punti, max_mean=319.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 19: 139 punti, max_mean=314.4min, overtime=0, RIFIUTATO
#       ❌ Cluster 2: 113 punti, max_mean=357.2min, overtime=0, RIFIUTATO
#       ❌ Cluster 20: 140 punti, max_mean=231.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 21: 137 punti, max_mean=289.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 22: 133 punti, max_mean=200.3min, overtime=0, RIFIUTATO
#       ❌ Cluster 23: 68 punti, max_mean=148.1min, overtime=0, RIFIUTATO
#       ❌ Cluster 3: 120 punti, max_mean=303.4min, overtime=0, RIFIUTATO
#       ✅ Cluster 4: 117 punti, max_mean=397.0min, overtime=1, motivo=mean_range
#       ❌ Cluster 5: 118 punti, max_mean=300.5min, overtime=0, RIFIUTATO
#       ✅ Cluster 6: 118 punti, max_mean=336.1min, overtime=1, motivo=overtime_ok
#       ❌ Cluster 7: 114 punti, max_mean=370.6min, overtime=0, RIFIUTATO
#       ❌ Cluster 8: 120 punti, max_mean=365.5min, overtime=0, RIFIUTATO
#       ❌ Cluster 9: 126 punti, max_mean=342.0min, overtime=0, RIFIUTATO
#    ✅ Cluster accettati: 4/23
#
# 🔍 DIAGNOSTICA ITERAZIONE 9:
#    📊 Punti prima: 2822
#    ✅ Cluster 1: 134 punti
#    ✅ Cluster 2: 137 punti
#    ✅ Cluster 3: 117 punti
#    ✅ Cluster 4: 118 punti
#    📊 Totale punti accettati: 506
#    📊 Location_ID unici accettati: 506
#    📊 Punti dopo rimozione: 2316
#    📊 Punti attesi dopo rimozione: 2316
#    📊 Rimossi effettivamente: 506
#    📊 Dovevano essere rimossi: 506
#    📊 DISCREPANZA: 0
#    ✅ Diagnostica completata
#
#
# 🔄 Iterazione 10: soglia = 1700 min
#    • Punti rimanenti: 2316

# %% [markdown]
# ### salvataggio risultati

# %%
final_performance.to_csv('clustering_methods_performances/euristic_complete_v2_4.csv')

with open('cluster_dicts/cluster_dict_euristic_complete_v2_4.pkl', 'wb') as f:
    pickle.dump(final_clusters, f)
